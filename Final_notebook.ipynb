# %% [markdown]
# Import all needed libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report

from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import RandomUnderSampler

from sklearn.feature_selection import SelectKBest, f_regression


from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import xgboost as xgb

from tqdm import tqdm
import warnings
import pickle
import joblib
import tkinter as tk
from tkinter import filedialog
import datetime
from sklearn.metrics import make_scorer

# %% [markdown]
# Picking the best model, resampling, number of features

# %%
warnings.filterwarnings("ignore")

# Initialize resampling techniques, models
resampling_techniques = [RandomOverSampler, SMOTE, SMOTETomek, RandomUnderSampler]
models = [RandomForestClassifier(class_weight='balanced'), xgb.XGBClassifier(), GradientBoostingClassifier(), DecisionTreeClassifier()]

#Importing Data
df = pd.read_csv('original_data.csv')
x = df.drop(['TARGET'], axis=1)
y = df['TARGET']

# Initialize results for storing the models, hyperparameters, and evaluation scores
results_modelPicking = []

# %%
#for loop to try all combinations of the best techniques used for unbalanced data, 15-20 min approx run time

# Initialize based on the number of iterations expected
progress_bar = tqdm(total=224)

# Set the range of features to pick
for p in range(3, 17):
    # Perform the test split before applying SelectKBest
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42, stratify=y)

    select = SelectKBest(score_func=f_regression, k=p)
    X_train_selected = select.fit_transform(X_train, y_train)
    X_test_selected = select.transform(X_test)

    # Loop through resampling techniques
    for resampling in resampling_techniques:
        resampler = resampling()
        X_train_resampled, y_train_resampled = resampler.fit_resample(X_train_selected, y_train)

        # Loop through picked models
        for model in models:
            best_model = model
            best_model.fit(X_train_resampled, y_train_resampled)
            y_pred = best_model.predict(X_test_selected)

            # Update the progress bar
            progress_bar.update(1)

            # Calculate metrics for our needs
            f1 = f1_score(y_test, y_pred, average='weighted')
            recall = recall_score(y_test, y_pred).mean()
            precision = precision_score(y_test, y_pred, average='weighted')
            accuracy = accuracy_score(y_test, y_pred)

            # Calculate precision for positive and negative classes
            accuracy_positive = accuracy_score(y_test[y_test == 1], y_pred[y_test == 1])
            accuracy_negative = accuracy_score(y_test[y_test == 0], y_pred[y_test == 0])
            avg_accPN = (accuracy_positive + accuracy_negative) / 2
            confusion = confusion_matrix(y_test, y_pred)
            report = classification_report(y_test, y_pred)

            result = {
                'Undersampling Technique': resampling.__name__,
                'Model': type(best_model).__name__,
                'F1 Score': f1,
                'Recall Score': recall,
                'Precision Score': precision,
                'Accuracy': accuracy,
                'Accuracy (Positive)': accuracy_positive,
                'Accuracy (Negative)': accuracy_negative,
                'Accuracy (Positive)+(Negative) AVG': avg_accPN,
                'SelectKBest N features': p,
                'confusion_matrix': confusion,
                'classification_report': report
            }
            results_modelPicking.append(result)

progress_bar.close()
# Out:
#   0%|          | 0/224 [01:26<?, ?it/s]
# 100%|██████████| 224/224 [27:36<00:00,  7.39s/it]

# %%
# Sort the results based on the average Precision
results_modelPicking = sorted(results_modelPicking, key=lambda x: x['Accuracy (Positive)+(Negative) AVG'],reverse=True)

# Print the sorted results
for result in results_modelPicking:
    print("Undersampling Technique:", result['Undersampling Technique'])
    print("Model:", result['Model'])
    print("F1 Score:", result['F1 Score'])
    print("Recall Score:", result['Recall Score'])
    print("Precision Score:", result['Precision Score'])
    print("Accuracy:", result['Accuracy'])
    print("Accuracy (Positive):", result['Accuracy (Positive)'])
    print("Accuracy (Negative):", result['Accuracy (Negative)'])
    print("Accuracy (Positive)+(Negative) AVG:", result['Accuracy (Positive)+(Negative) AVG'])
    print("SelectKBest N features:", result['SelectKBest N features'])
    print("confusion_matrix", result['confusion_matrix'])
    print("classification_report", result['classification_report'])
    print('__________________________________')
# Out:
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.8931194190695171
# Recall Score: 0.8525641025641025
# Precision Score: 0.9936241005558673
# Accuracy: 0.8154330374509319
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8152270545144198
# Accuracy (Positive)+(Negative) AVG: 0.8338955785392612
# SelectKBest N features: 4
# confusion_matrix [[22925  5196]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.82      0.89     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.898965226972332
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935557148088151
# Accuracy: 0.8250875269653782
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8250062231072863
# Accuracy (Positive)+(Negative) AVG: 0.832374906425438
# SelectKBest N features: 3
# confusion_matrix [[23200  4921]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.90     28121
#            1       0.03      0.84      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8950112667642494
# Recall Score: 0.8461538461538461
# Precision Score: 0.9935861396105637
# Accuracy: 0.8185451073310465
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8183919490772021
# Accuracy (Positive)+(Negative) AVG: 0.8322728976155241
# SelectKBest N features: 15
# confusion_matrix [[23014  5107]
#  [   24   132]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8778913627781897
# Recall Score: 0.8717948717948718
# Precision Score: 0.9937133549109892
# Accuracy: 0.7907486649927503
# Accuracy (Positive): 0.8717948717948718
# Accuracy (Negative): 0.7902990647558764
# Accuracy (Positive)+(Negative) AVG: 0.831046968275374
# SelectKBest N features: 6
# confusion_matrix [[22224  5897]
#  [   20   136]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88     28121
#            1       0.02      0.87      0.04       156
#
#     accuracy                           0.79     28277
#    macro avg       0.51      0.83      0.46     28277
# weighted avg       0.99      0.79      0.88     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.885493227168377
# Recall Score: 0.8589743589743589
# Precision Score: 0.9936448931870565
# Accuracy: 0.8029847579304735
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8026741581024857
# Accuracy (Positive)+(Negative) AVG: 0.8308242585384222
# SelectKBest N features: 6
# confusion_matrix [[22572  5549]
#  [   22   134]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     28121
#            1       0.02      0.86      0.05       156
#
#     accuracy                           0.80     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.80      0.89     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.8969179256919746
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935486039376369
# Accuracy: 0.8216925416416169
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8215924042530494
# Accuracy (Positive)+(Negative) AVG: 0.8306679969983195
# SelectKBest N features: 3
# confusion_matrix [[23104  5017]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.84      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9003700659042705
# Recall Score: 0.8333333333333334
# Precision Score: 0.9935169902753703
# Accuracy: 0.8274215793754641
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.8273887841826393
# Accuracy (Positive)+(Negative) AVG: 0.8303610587579864
# SelectKBest N features: 6
# confusion_matrix [[23267  4854]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91     28121
#            1       0.03      0.83      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.8924973211454975
# Recall Score: 0.8461538461538461
# Precision Score: 0.9935778148874487
# Accuracy: 0.8144074689677123
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8142313573486006
# Accuracy (Positive)+(Negative) AVG: 0.8301926017512233
# SelectKBest N features: 4
# confusion_matrix [[22897  5224]
#  [   24   132]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.896255221374646
# Recall Score: 0.8397435897435898
# Precision Score: 0.993546320954125
# Accuracy: 0.8205962442974856
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8204900252480353
# Accuracy (Positive)+(Negative) AVG: 0.8301168074958125
# SelectKBest N features: 5
# confusion_matrix [[23073  5048]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.84      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8908150926572203
# Recall Score: 0.8461538461538461
# Precision Score: 0.9935723076178713
# Accuracy: 0.8116490433921562
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.811457629529533
# Accuracy (Positive)+(Negative) AVG: 0.8288057378416895
# SelectKBest N features: 9
# confusion_matrix [[22819  5302]
#  [   24   132]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8786673811530108
# Recall Score: 0.8653846153846154
# Precision Score: 0.9936700534101648
# Accuracy: 0.791986420058705
# Accuracy (Positive): 0.8653846153846154
# Accuracy (Negative): 0.7915792468262153
# Accuracy (Positive)+(Negative) AVG: 0.8284819311054153
# SelectKBest N features: 12
# confusion_matrix [[22260  5861]
#  [   21   135]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88     28121
#            1       0.02      0.87      0.04       156
#
#     accuracy                           0.79     28277
#    macro avg       0.51      0.83      0.46     28277
# weighted avg       0.99      0.79      0.88     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8932525911051588
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935360841810638
# Accuracy: 0.8156452240336669
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8155115394189396
# Accuracy (Positive)+(Negative) AVG: 0.8276275645812647
# SelectKBest N features: 14
# confusion_matrix [[22933  5188]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.02      0.84      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.82      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8813127000897016
# Recall Score: 0.8589743589743589
# Precision Score: 0.9936324077013855
# Accuracy: 0.7962301517134066
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.7958820810070766
# Accuracy (Positive)+(Negative) AVG: 0.8274282199907177
# SelectKBest N features: 4
# confusion_matrix [[22381  5740]
#  [   22   134]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     28121
#            1       0.02      0.86      0.04       156
#
#     accuracy                           0.80     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.80      0.88     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.8968556706042847
# Recall Score: 0.8333333333333334
# Precision Score: 0.9935044596557132
# Accuracy: 0.8215864483502493
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.8215212830269194
# Accuracy (Positive)+(Negative) AVG: 0.8274273081801264
# SelectKBest N features: 5
# confusion_matrix [[23102  5019]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.83      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8890844897958654
# Recall Score: 0.8461538461538461
# Precision Score: 0.9935666911803429
# Accuracy: 0.8088198889556883
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8086127804843356
# Accuracy (Positive)+(Negative) AVG: 0.8273833133190909
# SelectKBest N features: 7
# confusion_matrix [[22739  5382]
#  [   24   132]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8957649396070179
# Recall Score: 0.8333333333333334
# Precision Score: 0.9935006228481202
# Accuracy: 0.819782862397001
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.819707691760606
# Accuracy (Positive)+(Negative) AVG: 0.8265205125469697
# SelectKBest N features: 3
# confusion_matrix [[23051  5070]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.83      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9065818562183743
# Recall Score: 0.8141025641025641
# Precision Score: 0.9934103334704608
# Accuracy: 0.8378187219294834
# Accuracy (Positive): 0.8141025641025641
# Accuracy (Negative): 0.8379502862629352
# Accuracy (Positive)+(Negative) AVG: 0.8260264251827496
# SelectKBest N features: 9
# confusion_matrix [[23564  4557]
#  [   29   127]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91     28121
#            1       0.03      0.81      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8979460652990249
# Recall Score: 0.8269230769230769
# Precision Score: 0.9934644810077431
# Accuracy: 0.8233900343034976
# Accuracy (Positive): 0.8269230769230769
# Accuracy (Negative): 0.8233704349062978
# Accuracy (Positive)+(Negative) AVG: 0.8251467559146873
# SelectKBest N features: 16
# confusion_matrix [[23154  4967]
#  [   27   129]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.83      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8898661715154236
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935247318885914
# Accuracy: 0.8100930084520989
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8099285231677394
# Accuracy (Positive)+(Negative) AVG: 0.8248360564556646
# SelectKBest N features: 10
# confusion_matrix [[22776  5345]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.84      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9051733848359581
# Recall Score: 0.8141025641025641
# Precision Score: 0.9934047427469688
# Accuracy: 0.8354493050889416
# Accuracy (Positive): 0.8141025641025641
# Accuracy (Negative): 0.8355677251875823
# Accuracy (Positive)+(Negative) AVG: 0.8248351446450732
# SelectKBest N features: 10
# confusion_matrix [[23497  4624]
#  [   29   127]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91     28121
#            1       0.03      0.81      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8892600763912104
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935227198243629
# Accuracy: 0.8091028043993351
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8089328260019203
# Accuracy (Positive)+(Negative) AVG: 0.824338207872755
# SelectKBest N features: 11
# confusion_matrix [[22748  5373]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.84      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8926091702710377
# Recall Score: 0.8333333333333334
# Precision Score: 0.9934896481283896
# Accuracy: 0.8145842911199915
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.8144802816400555
# Accuracy (Positive)+(Negative) AVG: 0.8239068074866944
# SelectKBest N features: 13
# confusion_matrix [[22904  5217]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.83      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9034025333772462
# Recall Score: 0.8141025641025641
# Precision Score: 0.9933977879623173
# Accuracy: 0.8324786929306504
# Accuracy (Positive): 0.8141025641025641
# Accuracy (Negative): 0.8325806336901248
# Accuracy (Positive)+(Negative) AVG: 0.8233415988963444
# SelectKBest N features: 6
# confusion_matrix [[23413  4708]
#  [   29   127]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91     28121
#            1       0.03      0.81      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9105172356583999
# Recall Score: 0.8012820512820513
# Precision Score: 0.9933405155400249
# Accuracy: 0.8444672348551826
# Accuracy (Positive): 0.8012820512820513
# Accuracy (Negative): 0.8447068027452793
# Accuracy (Positive)+(Negative) AVG: 0.8229944270136653
# SelectKBest N features: 8
# confusion_matrix [[23754  4367]
#  [   31   125]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.92     28121
#            1       0.03      0.80      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8873509464471373
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935164184197827
# Accuracy: 0.8059907345192205
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.805803492052203
# Accuracy (Positive)+(Negative) AVG: 0.8227735408978964
# SelectKBest N features: 11
# confusion_matrix [[22660  5461]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.84      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8911217593160181
# Recall Score: 0.8333333333333334
# Precision Score: 0.9934845358545745
# Accuracy: 0.8121441454185381
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.8120265993385726
# Accuracy (Positive)+(Negative) AVG: 0.822679966335953
# SelectKBest N features: 12
# confusion_matrix [[22835  5286]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.83      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8749944382784326
# Recall Score: 0.8589743589743589
# Precision Score: 0.9936139359883996
# Accuracy: 0.7861159246030343
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.7857117456704954
# Accuracy (Positive)+(Negative) AVG: 0.8223430523224271
# SelectKBest N features: 9
# confusion_matrix [[22095  6026]
#  [   22   134]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88     28121
#            1       0.02      0.86      0.04       156
#
#     accuracy                           0.79     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.79      0.87     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8866768674227117
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935142061747967
# Accuracy: 0.8048944371750894
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8047011130471889
# Accuracy (Positive)+(Negative) AVG: 0.8222223513953894
# SelectKBest N features: 5
# confusion_matrix [[22629  5492]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     28121
#            1       0.02      0.84      0.05       156
#
#     accuracy                           0.80     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.80      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8857623105088434
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935112148193134
# Accuracy: 0.8034091310959437
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8032075672984602
# Accuracy (Positive)+(Negative) AVG: 0.821475578521025
# SelectKBest N features: 8
# confusion_matrix [[22587  5534]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     28121
#            1       0.02      0.84      0.05       156
#
#     accuracy                           0.80     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.80      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8690057563247927
# Recall Score: 0.8653846153846154
# Precision Score: 0.993643049573496
# Accuracy: 0.7766382572408671
# Accuracy (Positive): 0.8653846153846154
# Accuracy (Negative): 0.7761459407560186
# Accuracy (Positive)+(Negative) AVG: 0.820765278070317
# SelectKBest N features: 14
# confusion_matrix [[21826  6295]
#  [   21   135]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.87     28121
#            1       0.02      0.87      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8724338672614801
# Recall Score: 0.8589743589743589
# Precision Score: 0.9936065661478657
# Accuracy: 0.7820490151006118
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.7816222751680239
# Accuracy (Positive)+(Negative) AVG: 0.8202983170711914
# SelectKBest N features: 3
# confusion_matrix [[21980  6141]
#  [   22   134]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.86      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9103097444304066
# Recall Score: 0.7948717948717948
# Precision Score: 0.9932967551222093
# Accuracy: 0.8441135905506242
# Accuracy (Positive): 0.7948717948717948
# Accuracy (Negative): 0.8443867572276946
# Accuracy (Positive)+(Negative) AVG: 0.8196292760497448
# SelectKBest N features: 10
# confusion_matrix [[23745  4376]
#  [   32   124]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.92     28121
#            1       0.03      0.79      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.875508231416244
# Recall Score: 0.8525641025641025
# Precision Score: 0.9935697288084145
# Accuracy: 0.7869293065035188
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.7865652003840546
# Accuracy (Positive)+(Negative) AVG: 0.8195646514740786
# SelectKBest N features: 10
# confusion_matrix [[22119  6002]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88     28121
#            1       0.02      0.85      0.04       156
#
#     accuracy                           0.79     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.79      0.88     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.90874359245991
# Recall Score: 0.7948717948717948
# Precision Score: 0.9932900278639671
# Accuracy: 0.8414612582664356
# Accuracy (Positive): 0.7948717948717948
# Accuracy (Negative): 0.841719711247822
# Accuracy (Positive)+(Negative) AVG: 0.8182957530598084
# SelectKBest N features: 7
# confusion_matrix [[23670  4451]
#  [   32   124]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91     28121
#            1       0.03      0.79      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9047549822475016
# Recall Score: 0.8012820512820513
# Precision Score: 0.9933164980205232
# Accuracy: 0.8347420164798246
# Accuracy (Positive): 0.8012820512820513
# Accuracy (Negative): 0.8349276341524128
# Accuracy (Positive)+(Negative) AVG: 0.818104842717232
# SelectKBest N features: 7
# confusion_matrix [[23479  4642]
#  [   31   125]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91     28121
#            1       0.03      0.80      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8687172399078473
# Recall Score: 0.8589743589743589
# Precision Score: 0.9935959704027789
# Accuracy: 0.7761785196449411
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.775719213399239
# Accuracy (Positive)+(Negative) AVG: 0.8173467861867989
# SelectKBest N features: 15
# confusion_matrix [[21814  6307]
#  [   22   134]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.87     28121
#            1       0.02      0.86      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: RandomForestClassifier
# F1 Score: 0.8723924698469944
# Recall Score: 0.8525641025641025
# Precision Score: 0.9935604872979672
# Accuracy: 0.7819782862397001
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.7815867145549589
# Accuracy (Positive)+(Negative) AVG: 0.8170754085595306
# SelectKBest N features: 16
# confusion_matrix [[21979  6142]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.85      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9104785408396777
# Recall Score: 0.782051282051282
# Precision Score: 0.9932117695899837
# Accuracy: 0.844396505994271
# Accuracy (Positive): 0.782051282051282
# Accuracy (Negative): 0.8447423633583443
# Accuracy (Positive)+(Negative) AVG: 0.8133968227048132
# SelectKBest N features: 9
# confusion_matrix [[23755  4366]
#  [   34   122]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.92     28121
#            1       0.03      0.78      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.81      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8899833000883556
# Recall Score: 0.8141025641025641
# Precision Score: 0.9933472641899085
# Accuracy: 0.8102698306043781
# Accuracy (Positive): 0.8141025641025641
# Accuracy (Negative): 0.8102485686853241
# Accuracy (Positive)+(Negative) AVG: 0.8121755663939441
# SelectKBest N features: 4
# confusion_matrix [[22785  5336]
#  [   29   127]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.81      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.81      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.912269160807909
# Recall Score: 0.7756410256410257
# Precision Score: 0.9931771033155714
# Accuracy: 0.8474378470134738
# Accuracy (Positive): 0.7756410256410257
# Accuracy (Negative): 0.8478361366949966
# Accuracy (Positive)+(Negative) AVG: 0.8117385811680111
# SelectKBest N features: 8
# confusion_matrix [[23842  4279]
#  [   35   121]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92     28121
#            1       0.03      0.78      0.05       156
#
#     accuracy                           0.85     28277
#    macro avg       0.51      0.81      0.49     28277
# weighted avg       0.99      0.85      0.91     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8845264088229708
# Recall Score: 0.8205128205128205
# Precision Score: 0.9933724563653672
# Accuracy: 0.8013933585599604
# Accuracy (Positive): 0.8205128205128205
# Accuracy (Negative): 0.8012872941929519
# Accuracy (Positive)+(Negative) AVG: 0.8109000573528862
# SelectKBest N features: 5
# confusion_matrix [[22533  5588]
#  [   28   128]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     28121
#            1       0.02      0.82      0.04       156
#
#     accuracy                           0.80     28277
#    macro avg       0.51      0.81      0.47     28277
# weighted avg       0.99      0.80      0.88     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9183454691864722
# Recall Score: 0.7628205128205128
# Precision Score: 0.9931211308747505
# Accuracy: 0.857834989567493
# Accuracy (Positive): 0.7628205128205128
# Accuracy (Negative): 0.8583620781622275
# Accuracy (Positive)+(Negative) AVG: 0.8105912954913701
# SelectKBest N features: 12
# confusion_matrix [[24138  3983]
#  [   37   119]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92     28121
#            1       0.03      0.76      0.06       156
#
#     accuracy                           0.86     28277
#    macro avg       0.51      0.81      0.49     28277
# weighted avg       0.99      0.86      0.92     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8786184966239807
# Recall Score: 0.8269230769230769
# Precision Score: 0.9933973957740534
# Accuracy: 0.7918803267673374
# Accuracy (Positive): 0.8269230769230769
# Accuracy (Negative): 0.7916859286654102
# Accuracy (Positive)+(Negative) AVG: 0.8093045027942436
# SelectKBest N features: 13
# confusion_matrix [[22263  5858]
#  [   27   129]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88     28121
#            1       0.02      0.83      0.04       156
#
#     accuracy                           0.79     28277
#    macro avg       0.51      0.81      0.46     28277
# weighted avg       0.99      0.79      0.88     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8703199091082104
# Recall Score: 0.8397435897435898
# Precision Score: 0.9934621294407784
# Accuracy: 0.7786893942073063
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.7783506987660467
# Accuracy (Positive)+(Negative) AVG: 0.8090471442548182
# SelectKBest N features: 16
# confusion_matrix [[21888  6233]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.87     28121
#            1       0.02      0.84      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.81      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9200083442559567
# Recall Score: 0.75
# Precision Score: 0.9930451181370411
# Accuracy: 0.8606995084344167
# Accuracy (Positive): 0.75
# Accuracy (Negative): 0.8613136090466199
# Accuracy (Positive)+(Negative) AVG: 0.8056568045233099
# SelectKBest N features: 11
# confusion_matrix [[24221  3900]
#  [   39   117]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92     28121
#            1       0.03      0.75      0.06       156
#
#     accuracy                           0.86     28277
#    macro avg       0.51      0.81      0.49     28277
# weighted avg       0.99      0.86      0.92     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9195984474007803
# Recall Score: 0.75
# Precision Score: 0.9930430030033268
# Accuracy: 0.8599922198252997
# Accuracy (Positive): 0.75
# Accuracy (Negative): 0.8606023967853206
# Accuracy (Positive)+(Negative) AVG: 0.8053011983926603
# SelectKBest N features: 11
# confusion_matrix [[24201  3920]
#  [   39   117]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92     28121
#            1       0.03      0.75      0.06       156
#
#     accuracy                           0.86     28277
#    macro avg       0.51      0.81      0.49     28277
# weighted avg       0.99      0.86      0.92     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9195369371738437
# Recall Score: 0.75
# Precision Score: 0.9930426862253119
# Accuracy: 0.8598861265339321
# Accuracy (Positive): 0.75
# Accuracy (Negative): 0.8604957149461256
# Accuracy (Positive)+(Negative) AVG: 0.8052478574730628
# SelectKBest N features: 12
# confusion_matrix [[24198  3923]
#  [   39   117]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92     28121
#            1       0.03      0.75      0.06       156
#
#     accuracy                           0.86     28277
#    macro avg       0.51      0.81      0.49     28277
# weighted avg       0.99      0.86      0.92     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9230937889443119
# Recall Score: 0.7371794871794872
# Precision Score: 0.9929773947852936
# Accuracy: 0.8660395374332497
# Accuracy (Positive): 0.7371794871794872
# Accuracy (Negative): 0.8667543828455603
# Accuracy (Positive)+(Negative) AVG: 0.8019669350125238
# SelectKBest N features: 13
# confusion_matrix [[24374  3747]
#  [   41   115]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93     28121
#            1       0.03      0.74      0.06       156
#
#     accuracy                           0.87     28277
#    macro avg       0.51      0.80      0.49     28277
# weighted avg       0.99      0.87      0.92     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8722970684715152
# Recall Score: 0.8205128205128205
# Precision Score: 0.9933304703320569
# Accuracy: 0.7818014640874209
# Accuracy (Positive): 0.8205128205128205
# Accuracy (Negative): 0.7815867145549589
# Accuracy (Positive)+(Negative) AVG: 0.8010497675338897
# SelectKBest N features: 7
# confusion_matrix [[21979  6142]
#  [   28   128]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.82      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.80      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9227678888979954
# Recall Score: 0.7307692307692307
# Precision Score: 0.9929336640741342
# Accuracy: 0.8654737065459561
# Accuracy (Positive): 0.7307692307692307
# Accuracy (Negative): 0.8662209736495857
# Accuracy (Positive)+(Negative) AVG: 0.7984951022094082
# SelectKBest N features: 13
# confusion_matrix [[24359  3762]
#  [   42   114]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93     28121
#            1       0.03      0.73      0.06       156
#
#     accuracy                           0.87     28277
#    macro avg       0.51      0.80      0.49     28277
# weighted avg       0.99      0.87      0.92     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8590369869470208
# Recall Score: 0.8333333333333334
# Precision Score: 0.9933803324883059
# Accuracy: 0.7610425434098383
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.760641513459692
# Accuracy (Positive)+(Negative) AVG: 0.7969874233965126
# SelectKBest N features: 10
# confusion_matrix [[21390  6731]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.86     28121
#            1       0.02      0.83      0.04       156
#
#     accuracy                           0.76     28277
#    macro avg       0.51      0.80      0.45     28277
# weighted avg       0.99      0.76      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8560826157557244
# Recall Score: 0.8333333333333334
# Precision Score: 0.9933710867938275
# Accuracy: 0.756480531881034
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.756054194374311
# Accuracy (Positive)+(Negative) AVG: 0.7946937638538222
# SelectKBest N features: 12
# confusion_matrix [[21261  6860]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.86     28121
#            1       0.02      0.83      0.04       156
#
#     accuracy                           0.76     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.76      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8518146060577934
# Recall Score: 0.8397435897435898
# Precision Score: 0.993405548994195
# Accuracy: 0.7499381122467023
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.7494399203442267
# Accuracy (Positive)+(Negative) AVG: 0.7945917550439082
# SelectKBest N features: 9
# confusion_matrix [[21075  7046]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86     28121
#            1       0.02      0.84      0.04       156
#
#     accuracy                           0.75     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.75      0.85     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8640931353319057
# Recall Score: 0.8205128205128205
# Precision Score: 0.9933029349124042
# Accuracy: 0.7688934469710366
# Accuracy (Positive): 0.8205128205128205
# Accuracy (Negative): 0.7686070907862451
# Accuracy (Positive)+(Negative) AVG: 0.7945599556495329
# SelectKBest N features: 4
# confusion_matrix [[21614  6507]
#  [   28   128]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.77      0.87     28121
#            1       0.02      0.82      0.04       156
#
#     accuracy                           0.77     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.77      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8582180512848266
# Recall Score: 0.8269230769230769
# Precision Score: 0.9933305867815341
# Accuracy: 0.7597694239134278
# Accuracy (Positive): 0.8269230769230769
# Accuracy (Negative): 0.7593968920024181
# Accuracy (Positive)+(Negative) AVG: 0.7931599844627475
# SelectKBest N features: 8
# confusion_matrix [[21355  6766]
#  [   27   129]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.86     28121
#            1       0.02      0.83      0.04       156
#
#     accuracy                           0.76     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.76      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8614154052690531
# Recall Score: 0.8205128205128205
# Precision Score: 0.9932940214992204
# Accuracy: 0.7647204441772465
# Accuracy (Positive): 0.8205128205128205
# Accuracy (Negative): 0.7644109384445787
# Accuracy (Positive)+(Negative) AVG: 0.7924618794786996
# SelectKBest N features: 8
# confusion_matrix [[21496  6625]
#  [   28   128]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.87     28121
#            1       0.02      0.82      0.04       156
#
#     accuracy                           0.76     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.76      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: RandomForestClassifier
# F1 Score: 0.8649790252710564
# Recall Score: 0.8141025641025641
# Precision Score: 0.9932593282603035
# Accuracy: 0.7702726597588145
# Accuracy (Positive): 0.8141025641025641
# Accuracy (Negative): 0.7700295153088439
# Accuracy (Positive)+(Negative) AVG: 0.792066039705704
# SelectKBest N features: 15
# confusion_matrix [[21654  6467]
#  [   29   127]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.77      0.87     28121
#            1       0.02      0.81      0.04       156
#
#     accuracy                           0.77     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.77      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8573522031554909
# Recall Score: 0.8205128205128205
# Precision Score: 0.9932805481012981
# Accuracy: 0.7584255755561057
# Accuracy (Positive): 0.8205128205128205
# Accuracy (Negative): 0.7580811493190143
# Accuracy (Positive)+(Negative) AVG: 0.7892969849159174
# SelectKBest N features: 3
# confusion_matrix [[21318  6803]
#  [   28   128]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.86     28121
#            1       0.02      0.82      0.04       156
#
#     accuracy                           0.76     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.76      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8520126740248365
# Recall Score: 0.8205128205128205
# Precision Score: 0.9932629145819117
# Accuracy: 0.750221027690349
# Accuracy (Positive): 0.8205128205128205
# Accuracy (Negative): 0.7498310870879414
# Accuracy (Positive)+(Negative) AVG: 0.785171953800381
# SelectKBest N features: 6
# confusion_matrix [[21086  7035]
#  [   28   128]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86     28121
#            1       0.02      0.82      0.03       156
#
#     accuracy                           0.75     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.75      0.85     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: RandomForestClassifier
# F1 Score: 0.8694504871716934
# Recall Score: 0.7884615384615384
# Precision Score: 0.9930900856866081
# Accuracy: 0.7772748169890724
# Accuracy (Positive): 0.7884615384615384
# Accuracy (Negative): 0.7772127591479677
# Accuracy (Positive)+(Negative) AVG: 0.7828371488047531
# SelectKBest N features: 14
# confusion_matrix [[21856  6265]
#  [   33   123]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.87     28121
#            1       0.02      0.79      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.78      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8484407063139022
# Recall Score: 0.8205128205128205
# Precision Score: 0.993251149906844
# Accuracy: 0.7447749054001486
# Accuracy (Positive): 0.8205128205128205
# Accuracy (Negative): 0.7443547526759361
# Accuracy (Positive)+(Negative) AVG: 0.7824337865943782
# SelectKBest N features: 11
# confusion_matrix [[20932  7189]
#  [   28   128]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85     28121
# ...
#            1       0.03      0.05      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: DecisionTreeClassifier
# F1 Score: 0.9880135468346094
# Recall Score: 0.05128205128205128
# Precision Score: 0.9894193468816331
# Accuracy: 0.9866322452876897
# Accuracy (Positive): 0.05128205128205128
# Accuracy (Negative): 0.9918210589950571
# Accuracy (Positive)+(Negative) AVG: 0.5215515551385542
# SelectKBest N features: 16
# confusion_matrix [[27891   230]
#  [  148     8]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.03      0.05      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: DecisionTreeClassifier
# F1 Score: 0.9872609808324028
# Recall Score: 0.05128205128205128
# Precision Score: 0.989384408847485
# Accuracy: 0.985182303639
# Accuracy (Positive): 0.05128205128205128
# Accuracy (Negative): 0.9903630738593934
# Accuracy (Positive)+(Negative) AVG: 0.5208225625707223
# SelectKBest N features: 14
# confusion_matrix [[27850   271]
#  [  148     8]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.03      0.05      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.52      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: RandomForestClassifier
# F1 Score: 0.9892018440656688
# Recall Score: 0.04487179487179487
# Precision Score: 0.9894383885498599
# Accuracy: 0.9889662976977756
# Accuracy (Positive): 0.04487179487179487
# Accuracy (Negative): 0.99420362007041
# Accuracy (Positive)+(Negative) AVG: 0.5195377074711024
# SelectKBest N features: 15
# confusion_matrix [[27958   163]
#  [  149     7]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.04      0.04      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: RandomForestClassifier
# F1 Score: 0.9889984401546856
# Recall Score: 0.04487179487179487
# Precision Score: 0.9894225189383927
# Accuracy: 0.9885772889627612
# Accuracy (Positive): 0.04487179487179487
# Accuracy (Negative): 0.9938124533266953
# Accuracy (Positive)+(Negative) AVG: 0.5193421240992451
# SelectKBest N features: 14
# confusion_matrix [[27947   174]
#  [  149     7]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.04      0.04      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: RandomForestClassifier
# F1 Score: 0.9889615033176276
# Recall Score: 0.04487179487179487
# Precision Score: 0.9894198116942716
# Accuracy: 0.9885065601018496
# Accuracy (Positive): 0.04487179487179487
# Accuracy (Negative): 0.9937413321005654
# Accuracy (Positive)+(Negative) AVG: 0.5193065634861801
# SelectKBest N features: 15
# confusion_matrix [[27945   176]
#  [  149     7]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.04      0.04      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: DecisionTreeClassifier
# F1 Score: 0.990113787637305
# Recall Score: 0.038461538461538464
# Precision Score: 0.9894687463831833
# Accuracy: 0.9907698836510238
# Accuracy (Positive): 0.038461538461538464
# Accuracy (Negative): 0.9960527719497884
# Accuracy (Positive)+(Negative) AVG: 0.5172571552056634
# SelectKBest N features: 15
# confusion_matrix [[28010   111]
#  [  150     6]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.05      0.04      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: XGBClassifier
# F1 Score: 0.9900765189353052
# Recall Score: 0.038461538461538464
# Precision Score: 0.9894636152450895
# Accuracy: 0.9906991547901121
# Accuracy (Positive): 0.038461538461538464
# Accuracy (Negative): 0.9959816507236585
# Accuracy (Positive)+(Negative) AVG: 0.5172215945925985
# SelectKBest N features: 15
# confusion_matrix [[28008   113]
#  [  150     6]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.05      0.04      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: RandomForestClassifier
# F1 Score: 0.9892247072966631
# Recall Score: 0.038461538461538464
# Precision Score: 0.9893773987719984
# Accuracy: 0.9890723909891431
# Accuracy (Positive): 0.038461538461538464
# Accuracy (Negative): 0.9943458625226699
# Accuracy (Positive)+(Negative) AVG: 0.5164037004921042
# SelectKBest N features: 14
# confusion_matrix [[27962   159]
#  [  150     6]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.04      0.04      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: RandomForestClassifier
# F1 Score: 0.9914251399466759
# Recall Score: 0.03205128205128205
# Precision Score: 0.9898059863905675
# Accuracy: 0.9933161226438448
# Accuracy (Positive): 0.03205128205128205
# Accuracy (Negative): 0.9986486967035312
# Accuracy (Positive)+(Negative) AVG: 0.5153499893774066
# SelectKBest N features: 14
# confusion_matrix [[28083    38]
#  [  151     5]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.12      0.03      0.05       156
#
#     accuracy                           0.99     28277
#    macro avg       0.56      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: XGBClassifier
# F1 Score: 0.9902974282604063
# Recall Score: 0.03205128205128205
# Precision Score: 0.9894209736448715
# Accuracy: 0.991194256816494
# Accuracy (Positive): 0.03205128205128205
# Accuracy (Negative): 0.996515059919633
# Accuracy (Positive)+(Negative) AVG: 0.5142831709854575
# SelectKBest N features: 15
# confusion_matrix [[28023    98]
#  [  151     5]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.05      0.03      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.51      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: DecisionTreeClassifier
# F1 Score: 0.989853333612533
# Recall Score: 0.03205128205128205
# Precision Score: 0.9893658199874856
# Accuracy: 0.9903455104855536
# Accuracy (Positive): 0.03205128205128205
# Accuracy (Negative): 0.9956616052060737
# Accuracy (Positive)+(Negative) AVG: 0.5138564436286779
# SelectKBest N features: 14
# confusion_matrix [[27999   122]
#  [  151     5]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.04      0.03      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.51      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: DecisionTreeClassifier
# F1 Score: 0.9891732839156683
# Recall Score: 0.03205128205128205
# Precision Score: 0.9893097969415509
# Accuracy: 0.9890370265586873
# Accuracy (Positive): 0.03205128205128205
# Accuracy (Negative): 0.9943458625226699
# Accuracy (Positive)+(Negative) AVG: 0.513198572286976
# SelectKBest N features: 16
# confusion_matrix [[27962   159]
#  [  151     5]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.03      0.03      0.03       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: RandomForestClassifier
# F1 Score: 0.9912779843464331
# Recall Score: 0.02564102564102564
# Precision Score: 0.9896084264289121
# Accuracy: 0.9931393004915656
# Accuracy (Positive): 0.02564102564102564
# Accuracy (Negative): 0.9985064542512713
# Accuracy (Positive)+(Negative) AVG: 0.5120737399461485
# SelectKBest N features: 15
# confusion_matrix [[28079    42]
#  [  152     4]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.09      0.03      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.54      0.51      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: XGBClassifier
# F1 Score: 0.9900173277387467
# Recall Score: 0.02564102564102564
# Precision Score: 0.9893093455673089
# Accuracy: 0.990734519220568
# Accuracy (Positive): 0.02564102564102564
# Accuracy (Negative): 0.9960883325628533
# Accuracy (Positive)+(Negative) AVG: 0.5108646791019394
# SelectKBest N features: 14
# confusion_matrix [[28011   110]
#  [  152     4]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.04      0.03      0.03       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: XGBClassifier
# F1 Score: 0.9903058436942622
# Recall Score: 0.019230769230769232
# Precision Score: 0.9892603638748583
# Accuracy: 0.9913710789687732
# Accuracy (Positive): 0.019230769230769232
# Accuracy (Negative): 0.9967639842110878
# Accuracy (Positive)+(Negative) AVG: 0.5079973767209285
# SelectKBest N features: 16
# confusion_matrix [[28030    91]
#  [  153     3]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.03      0.02      0.02       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: XGBClassifier
# F1 Score: 0.9900686349898581
# Recall Score: 0.019230769230769232
# Precision Score: 0.9892364807426887
# Accuracy: 0.9909113413728472
# Accuracy (Positive): 0.019230769230769232
# Accuracy (Negative): 0.9963016962412432
# Accuracy (Positive)+(Negative) AVG: 0.5077662327360062
# SelectKBest N features: 14
# confusion_matrix [[28017   104]
#  [  153     3]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.03      0.02      0.02       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: RandomForestClassifier
# F1 Score: 0.9918330087364776
# Recall Score: 0.01282051282051282
# Precision Score: 0.9909048729256792
# Accuracy: 0.9944124199879761
# Accuracy (Positive): 0.01282051282051282
# Accuracy (Negative): 0.9998577575477401
# Accuracy (Positive)+(Negative) AVG: 0.5063391351841264
# SelectKBest N features: 16
# confusion_matrix [[28117     4]
#  [  154     2]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.33      0.01      0.02       156
#
#     accuracy                           0.99     28277
#    macro avg       0.66      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: RandomForestClassifier
# F1 Score: 0.9910799008005069
# Recall Score: 0.01282051282051282
# Precision Score: 0.9892928144261924
# Accuracy: 0.9929624783392863
# Accuracy (Positive): 0.01282051282051282
# Accuracy (Negative): 0.9983997724120763
# Accuracy (Positive)+(Negative) AVG: 0.5056101426162946
# SelectKBest N features: 16
# confusion_matrix [[28076    45]
#  [  154     2]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.04      0.01      0.02       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: RandomForestClassifier
# F1 Score: 0.991043418322256
# Recall Score: 0.01282051282051282
# Precision Score: 0.9892828480239532
# Accuracy: 0.9928917494783747
# Accuracy (Positive): 0.01282051282051282
# Accuracy (Negative): 0.9983286511859465
# Accuracy (Positive)+(Negative) AVG: 0.5055745820032297
# SelectKBest N features: 16
# confusion_matrix [[28074    47]
#  [  154     2]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.04      0.01      0.02       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: XGBClassifier
# F1 Score: 0.9907766058051162
# Recall Score: 0.0
# Precision Score: 0.9889862360040299
# Accuracy: 0.9925734696042721
# Accuracy (Positive): 0.0
# Accuracy (Negative): 0.9980797268944916
# Accuracy (Positive)+(Negative) AVG: 0.4990398634472458
# SelectKBest N features: 16
# confusion_matrix [[28067    54]
#  [  156     0]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.00      0.00      0.00       156
#
#     accuracy                           0.99     28277
#    macro avg       0.50      0.50      0.50     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________

# %% [markdown]
# We conclude that the best model is **GradientBoostingClassifier**

# %% [markdown]
# The best regenrative solution and to avoid overfit we will use **GradientBoostingClassifier model**, and **SMOTETomek** resampler

# %% [markdown]
# **Hyperparameters selection**

# %% [markdown]
# we avoided gridsearch to take a deeper understanding with the best parameters we should use

# %%
#Initialization
results_ParamsPicking = []
best_model = None
best_avg_accPN = 0.0

#intialize the progress bar
progress_bar = tqdm(total=2916)

# Define the hyperparameters to search over
learning_rates = [0.1]
n_estimators = [50, 100, 200]
max_depths = [3, 5, 7]
min_samples_splits = [2, 5, 10]
min_samples_leafs = [1, 5, 10]
subsamples = [0.8,1]
max_features = ['sqrt', 'log2']

#timestamp for exporting text file
timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S")

for p in range(6, 15):
    # Perform the test split before applying SelectKBest
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42, stratify=y)

    select = SelectKBest(score_func=f_regression, k=p)
    X_train_selected = select.fit_transform(X_train, y_train)
    X_test_selected = select.transform(X_test)

    resampler = SMOTETomek()
    X_train_resampled, y_train_resampled = resampler.fit_resample(X_train_selected, y_train)

    for lr in learning_rates:
        for est in n_estimators:
            for depth in max_depths:
                for split in min_samples_splits:
                    for leaf in min_samples_leafs:
                        for subsample in subsamples:
                            for feature in max_features:
                                model = GradientBoostingClassifier(learning_rate=lr, n_estimators=est, max_depth=depth,
                                                                   min_samples_split=split, min_samples_leaf=leaf,
                                                                   subsample=subsample, max_features=feature)
                                selected_model = model.fit(X_train_resampled, y_train_resampled)
                                y_pred = selected_model.predict(X_test_selected)

                                # Calculate results we need for better understanding

                                # Calculate precision for positive and negative classes
                                accuracy_positive = accuracy_score(y_test[y_test == 1], y_pred[y_test == 1])
                                accuracy_negative = accuracy_score(y_test[y_test == 0], y_pred[y_test == 0])
                                avg_accPN = (accuracy_positive + accuracy_negative) / 2
                                f1 = f1_score(y_test, y_pred, average='weighted')
                                recall = recall_score(y_test, y_pred, average='weighted')
                                precision = precision_score(y_test, y_pred, average='weighted')
                                accuracy = accuracy_score(y_test, y_pred)

                                # Update the progress bar
                                progress_bar.update(1)

                                confusion = confusion_matrix(y_test, y_pred)
                                report = classification_report(y_test, y_pred)

                                result = {
                                    'F1 Score': f1,
                                    'Recall Score': recall,
                                    'Precision Score': precision,
                                    'Accuracy': accuracy,
                                    'Accuracy (Positive)': accuracy_positive,
                                    'Accuracy (Negative)': accuracy_negative,
                                    'Accuracy (Positive)+(Negative) AVG': avg_accPN,
                                    'SelectKBest N features': p,
                                    'learning_rate': lr,
                                    'n_estimators': est,
                                    'max_depth': depth,
                                    'min_samples_split': split,
                                    'min_samples_leaf': leaf,
                                    'subsample': subsample,
                                    'max_features': feature,
                                    'confusion_matrix': confusion,
                                    'classification_report': report}
                                results_ParamsPicking.append(result)

                                # Save the results incrementally in a text file
                                filename = f'resultsresults_ParamsPicking_{timestamp}.txt'
                                with open(filename, 'a') as file:
                                    file.write(str(result))
                                    file.write('\n')
                                    file.write('___________________________')

progress_bar.close()
# Out:
# 2916it [8:14:51, 10.18s/it]

# %%
# Sort the results based on the average precision, or change to any metric we want

results_ParamsPicking = sorted(results_ParamsPicking, key=lambda x: x['Accuracy (Positive)'], reverse=True)

for result in results_ParamsPicking:
    print("F1 Score:", result['F1 Score'])
    print("Recall Score:", result['Recall Score'])
    print("Precision Score:", result['Precision Score'])
    print("Accuracy:", result['Accuracy'])
    print("Accuracy (Positive):", result['Accuracy (Positive)'])
    print("Accuracy (Negative):", result['Accuracy (Negative)'])
    print("Accuracy (Positive)+(Negative) AVG:", result['Accuracy (Positive)+(Negative) AVG'])
    print("SelectKBest N features:", result['SelectKBest N features'])
    print("Learning Rate:", result['learning_rate'])
    print("Number of Estimators:", result['n_estimators'])
    print("Max Depth:", result['max_depth'])
    print("Min Samples Split:", result['min_samples_split'])
    print("Min Samples Leaf:", result['min_samples_leaf'])
    print("Subsample:", result['subsample'])
    print("Max Features:", result['max_features'])
    print(result['confusion_matrix'])
    print(result['classification_report'])
    print('__________________________________')
# Out:
# F1 Score: 0.8946427353357495
# Recall Score: 0.8179439120132971
# Precision Score: 0.9936731500287881
# Accuracy: 0.8179439120132971
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8177162974289677
# Accuracy (Positive)+(Negative) AVG: 0.8383453282016633
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: log2
# [[22995  5126]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.89     28277
#
# __________________________________
# F1 Score: 0.8934614616970262
# Recall Score: 0.8159988683382254
# Precision Score: 0.9936694188787843
# Accuracy: 0.8159988683382254
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8157604637103943
# Accuracy (Positive)+(Negative) AVG: 0.8373674113423766
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[22940  5181]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.89     28277
#
# __________________________________
# F1 Score: 0.8902703893332323
# Recall Score: 0.81076493263076
# Precision Score: 0.9936594696012402
# Accuracy: 0.81076493263076
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8104974929767789
# Accuracy (Positive)+(Negative) AVG: 0.8347359259755689
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[22792  5329]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.86      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8902703893332323
# Recall Score: 0.81076493263076
# Precision Score: 0.9936594696012402
# Accuracy: 0.81076493263076
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8104974929767789
# Accuracy (Positive)+(Negative) AVG: 0.8347359259755689
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[22792  5329]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.86      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8975335564885718
# Recall Score: 0.8227181101248364
# Precision Score: 0.9936385050332904
# Accuracy: 0.8227181101248364
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8225525408058035
# Accuracy (Positive)+(Negative) AVG: 0.837558321684953
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: log2
# [[23131  4990]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8969783397770049
# Recall Score: 0.8217986349329844
# Precision Score: 0.9936366712748901
# Accuracy: 0.8217986349329844
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8216279648661143
# Accuracy (Positive)+(Negative) AVG: 0.8370960337151084
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: log2
# [[23105  5016]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8969569743317414
# Recall Score: 0.8217632705025285
# Precision Score: 0.9936366008416865
# Accuracy: 0.8217632705025285
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8215924042530494
# Accuracy (Positive)+(Negative) AVG: 0.8370782534085759
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 100
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: sqrt
# [[23104  5017]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8969356080743373
# Recall Score: 0.8217279060720727
# Precision Score: 0.9936365304155282
# Accuracy: 0.8217279060720727
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8215568436399844
# Accuracy (Positive)+(Negative) AVG: 0.8370604731020435
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: sqrt
# [[23103  5018]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8968928731228685
# Recall Score: 0.821657177211161
# Precision Score: 0.993636389584321
# Accuracy: 0.821657177211161
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8214857224138544
# Accuracy (Positive)+(Negative) AVG: 0.8370249124889785
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[23101  5020]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8968073934716145
# Recall Score: 0.8215157194893377
# Precision Score: 0.9936361080061551
# Accuracy: 0.8215157194893377
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8213434799615945
# Accuracy (Positive)+(Negative) AVG: 0.8369537912628485
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 100
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: sqrt
# [[23097  5024]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8967646487708733
# Recall Score: 0.8214449906284259
# Precision Score: 0.9936359672590889
# Accuracy: 0.8214449906284259
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8212723587354646
# Accuracy (Positive)+(Negative) AVG: 0.8369182306497835
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 100
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: log2
# [[23095  5026]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.896657772796101
# Recall Score: 0.8212681684761467
# Precision Score: 0.9936356155135424
# Accuracy: 0.8212681684761467
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8210945556701398
# Accuracy (Positive)+(Negative) AVG: 0.8368293291171212
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt
# [[23090  5031]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.896636395162454
# Recall Score: 0.8212328040456909
# Precision Score: 0.9936355451853144
# Accuracy: 0.8212328040456909
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8210589950570748
# Accuracy (Positive)+(Negative) AVG: 0.8368115488105887
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: sqrt
# [[23089  5032]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8965936374559893
# Recall Score: 0.8211620751847791
# Precision Score: 0.9936354045496862
# Accuracy: 0.8211620751847791
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8209878738309448
# Accuracy (Positive)+(Negative) AVG: 0.8367759881975236
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: log2
# [[23087  5034]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.896572257383052
# Recall Score: 0.8211267107543233
# Precision Score: 0.9936353342422727
# Accuracy: 0.8211267107543233
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8209523132178799
# Accuracy (Positive)+(Negative) AVG: 0.8367582078909912
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: log2
# [[23086  5035]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8964653448189303
# Recall Score: 0.8209498886020441
# Precision Score: 0.9936349828089449
# Accuracy: 0.8209498886020441
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.820774510152555
# Accuracy (Positive)+(Negative) AVG: 0.8366693063583288
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 100
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: log2
# [[23081  5040]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8964225740990969
# Recall Score: 0.8208791597411323
# Precision Score: 0.993634842283902
# Accuracy: 0.8208791597411323
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8207033889264251
# Accuracy (Positive)+(Negative) AVG: 0.8366337457452638
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: sqrt
# [[23079  5042]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8963370228953442
# Recall Score: 0.820737702019309
# Precision Score: 0.9936345613163038
# Accuracy: 0.820737702019309
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8205611464741652
# Accuracy (Positive)+(Negative) AVG: 0.8365626245191339
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: log2
# [[23075  5046]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.896251458669627
# Recall Score: 0.8205962442974856
# Precision Score: 0.9936342804583369
# Accuracy: 0.8205962442974856
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8204189040219053
# Accuracy (Positive)+(Negative) AVG: 0.8364915032930039
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[23071  5050]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8960374911091855
# Recall Score: 0.8202425999929271
# Precision Score: 0.9936335787902917
# Accuracy: 0.8202425999929271
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8200632978912556
# Accuracy (Positive)+(Negative) AVG: 0.836313700227679
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: log2
# [[23061  5060]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8957806224899932
# Recall Score: 0.819818226827457
# Precision Score: 0.9936327376803871
# Accuracy: 0.819818226827457
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.819636570534476
# Accuracy (Positive)+(Negative) AVG: 0.8361003365492893
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[23049  5072]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8957377996403223
# Recall Score: 0.8197474979665452
# Precision Score: 0.9936325975892524
# Accuracy: 0.8197474979665452
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8195654493083461
# Accuracy (Positive)+(Negative) AVG: 0.8360647759362243
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: log2
# [[23047  5074]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8956307282431205
# Recall Score: 0.819570675814266
# Precision Score: 0.9936322474780086
# Accuracy: 0.819570675814266
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8193876462430212
# Accuracy (Positive)+(Negative) AVG: 0.8359758744035619
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: sqrt
# [[23042  5079]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895587893973779
# Recall Score: 0.8194999469533543
# Precision Score: 0.9936321074800123
# Accuracy: 0.8194999469533543
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8193165250168913
# Accuracy (Positive)+(Negative) AVG: 0.8359403137904969
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[23040  5081]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895587893973779
# Recall Score: 0.8194999469533543
# Precision Score: 0.9936321074800123
# Accuracy: 0.8194999469533543
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8193165250168913
# Accuracy (Positive)+(Negative) AVG: 0.8359403137904969
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: sqrt
# [[23040  5081]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8955664756152003
# Recall Score: 0.8194645825228984
# Precision Score: 0.9936320374909531
# Accuracy: 0.8194645825228984
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8192809644038264
# Accuracy (Positive)+(Negative) AVG: 0.8359225334839644
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[23039  5082]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895545056440603
# Recall Score: 0.8194292180924426
# Precision Score: 0.9936319675085111
# Accuracy: 0.8194292180924426
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8192454037907614
# Accuracy (Positive)+(Negative) AVG: 0.835904753177432
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: sqrt
# [[23038  5083]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8955236364499282
# Recall Score: 0.8193938536619868
# Precision Score: 0.9936318975326799
# Accuracy: 0.8193938536619868
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8192098431776964
# Accuracy (Positive)+(Negative) AVG: 0.8358869728708995
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: sqrt
# [[23037  5084]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8953736736600306
# Recall Score: 0.8191463026487958
# Precision Score: 0.9936314078864259
# Accuracy: 0.8191463026487958
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8189609188862416
# Accuracy (Positive)+(Negative) AVG: 0.835762510725172
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: log2
# [[23030  5091]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8949449880069694
# Recall Score: 0.8184390140396789
# Precision Score: 0.993630010660745
# Accuracy: 0.8184390140396789
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8182497066249422
# Accuracy (Positive)+(Negative) AVG: 0.8354069045945224
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[23010  5111]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.89     28277
#
# __________________________________
# F1 Score: 0.8931624417809672
# Recall Score: 0.8155037663118435
# Precision Score: 0.9936242391119655
# Accuracy: 0.8155037663118435
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8152981757405497
# Accuracy (Positive)+(Negative) AVG: 0.8339311391523261
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: sqrt
# [[22927  5194]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.82      0.89     28277
#
# __________________________________
# F1 Score: 0.8926674818077908
# Recall Score: 0.8146903844113591
# Precision Score: 0.993622647135384
# Accuracy: 0.8146903844113591
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8144802816400555
# Accuracy (Positive)+(Negative) AVG: 0.833522192102079
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt
# [[22904  5217]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.89264595192592
# Recall Score: 0.8146550199809032
# Precision Score: 0.9936225779889776
# Accuracy: 0.8146550199809032
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8144447210269905
# Accuracy (Positive)+(Negative) AVG: 0.8335044117955466
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: log2
# [[22903  5218]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8925167553269798
# Recall Score: 0.8144428333981681
# Precision Score: 0.993622163231744
# Accuracy: 0.8144428333981681
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8142313573486006
# Accuracy (Positive)+(Negative) AVG: 0.8333977299563515
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: sqrt
# [[22897  5224]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.892365988448967
# Recall Score: 0.8141952823849772
# Precision Score: 0.9936216796096753
# Accuracy: 0.8141952823849772
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8139824330571459
# Accuracy (Positive)+(Negative) AVG: 0.8332732678106243
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: log2
# [[22890  5231]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8922582730776222
# Recall Score: 0.814018460232698
# Precision Score: 0.9936213343366229
# Accuracy: 0.814018460232698
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.813804629991821
# Accuracy (Positive)+(Negative) AVG: 0.8331843662779618
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: log2
# [[22885  5236]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8922367275281671
# Recall Score: 0.8139830958022422
# Precision Score: 0.9936212652990652
# Accuracy: 0.8139830958022422
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.813769069378756
# Accuracy (Positive)+(Negative) AVG: 0.8331665859714292
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: sqrt
# [[22884  5237]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8921720859283677
# Recall Score: 0.8138770025108746
# Precision Score: 0.993621058220393
# Accuracy: 0.8138770025108746
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8136623875395612
# Accuracy (Positive)+(Negative) AVG: 0.8331132450518319
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: sqrt
# [[22881  5240]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8919996720080071
# Recall Score: 0.8135940870672278
# Precision Score: 0.9936205062589245
# Accuracy: 0.8135940870672278
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8133779026350414
# Accuracy (Positive)+(Negative) AVG: 0.832971002599572
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: log2
# [[22873  5248]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8918703268837596
# Recall Score: 0.8133819004844927
# Precision Score: 0.993620092523488
# Accuracy: 0.8133819004844927
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8131645389566516
# Accuracy (Positive)+(Negative) AVG: 0.8328643207603771
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt
# [[22867  5254]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8918056431687054
# Recall Score: 0.8132758071931252
# Precision Score: 0.9936198857310798
# Accuracy: 0.8132758071931252
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8130578571174567
# Accuracy (Positive)+(Negative) AVG: 0.8328109798407797
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: sqrt
# [[22864  5257]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8917625165602074
# Recall Score: 0.8132050783322134
# Precision Score: 0.9936197478972619
# Accuracy: 0.8132050783322134
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8129867358913268
# Accuracy (Positive)+(Negative) AVG: 0.8327754192277146
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[22862  5259]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8916762534247815
# Recall Score: 0.8130636206103901
# Precision Score: 0.9936194722961109
# Accuracy: 0.8130636206103901
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8128444934390668
# Accuracy (Positive)+(Negative) AVG: 0.8327042980015846
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: sqrt
# [[22858  5263]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8915468339184998
# Recall Score: 0.812851434027655
# Precision Score: 0.9936190590599124
# Accuracy: 0.812851434027655
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8126311297606771
# Accuracy (Positive)+(Negative) AVG: 0.8325976161623898
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt
# [[22852  5269]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8914605377067191
# Recall Score: 0.8127099763058316
# Precision Score: 0.9936187836789353
# Accuracy: 0.8127099763058316
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8124888873084172
# Accuracy (Positive)+(Negative) AVG: 0.8325264949362599
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt
# [[22848  5273]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8909856718270867
# Recall Score: 0.8119319588358029
# Precision Score: 0.9936172706367786
# Accuracy: 0.8119319588358029
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8117065538209879
# Accuracy (Positive)+(Negative) AVG: 0.8321353281925452
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: sqrt
# [[22826  5295]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8908344940634737
# Recall Score: 0.811684407822612
# Precision Score: 0.9936167897592375
# Accuracy: 0.811684407822612
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.811457629529533
# Accuracy (Positive)+(Negative) AVG: 0.8320108660468177
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[22819  5302]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8906400629603184
# Recall Score: 0.8113661279485094
# Precision Score: 0.9936161718696039
# Accuracy: 0.8113661279485094
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8111375840119484
# Accuracy (Positive)+(Negative) AVG: 0.8318508432880254
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: log2
# [[22810  5311]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8903807169579198
# Recall Score: 0.8109417547830392
# Precision Score: 0.9936153486778669
# Accuracy: 0.8109417547830392
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8107108566551687
# Accuracy (Positive)+(Negative) AVG: 0.8316374796096356
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: log2
# [[22798  5323]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8879543753481706
# Recall Score: 0.8069809385719843
# Precision Score: 0.9936077003252551
# Accuracy: 0.8069809385719843
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8067280679918922
# Accuracy (Positive)+(Negative) AVG: 0.8296460852779974
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: log2
# [[22686  5435]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.8874548122900164
# Recall Score: 0.8061675566714998
# Precision Score: 0.9936061370540692
# Accuracy: 0.8061675566714998
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8059101738913979
# Accuracy (Positive)+(Negative) AVG: 0.8292371382277501
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: sqrt
# [[22663  5458]
#  [   23   133]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# F1 Score: 0.9014487579836099
# Recall Score: 0.8292251653287124
# Precision Score: 0.9936080474819786
# Accuracy: 0.8292251653287124
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8291312542228229
# Accuracy (Positive)+(Negative) AVG: 0.8376425501883344
# SelectKBest N features: 11
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: log2
# [[23316  4805]
#  [   24   132]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# F1 Score: 0.9014275630281222
# Recall Score: 0.8291898008982566
# Precision Score: 0.9936079737956163
# Accuracy: 0.8291898008982566
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8290956936097579
# Accuracy (Positive)+(Negative) AVG: 0.837624769881802
# SelectKBest N features: 12
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: sqrt
# [[23315  4806]
#  [   24   132]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# F1 Score: 0.9005154227699149
# Recall Score: 0.8276691303886551
# Precision Score: 0.9936048130698795
# Accuracy: 0.8276691303886551
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8275665872479642
# Accuracy (Positive)+(Negative) AVG: 0.8368602167009052
# SelectKBest N features: 7
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[23272  4849]
#  [   24   132]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# F1 Score: 0.899750630000034
# Recall Score: 0.8263960108922446
# Precision Score: 0.9936021782969988
# Accuracy: 0.8263960108922446
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8262864051776253
# Accuracy (Positive)+(Negative) AVG: 0.8362201256657358
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: sqrt
# [[23236  4885]
#  [   24   132]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# F1 Score: 0.8994954675684358
# Recall Score: 0.8259716377267744
# Precision Score: 0.9936013022857314
# Accuracy: 0.8259716377267744
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8258596778208457
# Accuracy (Positive)+(Negative) AVG: 0.8360067619873459
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 100
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: log2
# [[23224  4897]
#  [   24   132]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# F1 Score: 0.899325294882643
# Recall Score: 0.8256887222831276
# Precision Score: 0.9936007188911704
# Accuracy: 0.8256887222831276
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8255751929163259
# Accuracy (Positive)+(Negative) AVG: 0.835864519535086
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: sqrt
# [[23216  4905]
#  [   24   132]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# F1 Score: 0.8992614668357403
# Recall Score: 0.82558262899176
# Precision Score: 0.993600500243706
# Accuracy: 0.82558262899176
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8254685110771309
# Accuracy (Positive)+(Negative) AVG: 0.8358111786154885
# SelectKBest N features: 6
# Learning Rate: 0.1
# Number of Estimators: 100
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: sqrt
# [[23213  4908]
#  [   24   132]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# F1 Score: 0.8992401892087474
# Recall Score: 0.8255472645613042
# Precision Score: 0.9936004273763714
# Accuracy: 0.8255472645613042
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.825432950464066
# Accuracy (Positive)+(Negative) AVG: 0.835793398308956
# SelectKBest N features: 8
# Learning Rate: 0.1
# Number of Estimators: 100
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: sqrt
# [[23212  4909]
#  [   24   132]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# F1 Score: 0.8990699391796717
# Recall Score: 0.8252643491176574
# Precision Score: 0.9935998447094109
# ...
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: sqrt
# [[27569   552]
#  [  136    20]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.13      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.52      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9823088912544599
# Recall Score: 0.9752448986809067
# Precision Score: 0.9897881869627415
# Accuracy: 0.9752448986809067
# Accuracy (Positive): 0.1282051282051282
# Accuracy (Negative): 0.9799438142313573
# Accuracy (Positive)+(Negative) AVG: 0.5540744712182428
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: log2
# [[27557   564]
#  [  136    20]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.13      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9830141375098439
# Recall Score: 0.9766241114686848
# Precision Score: 0.9897636547972452
# Accuracy: 0.9766241114686848
# Accuracy (Positive): 0.12179487179487179
# Accuracy (Negative): 0.9813662387539561
# Accuracy (Positive)+(Negative) AVG: 0.551580555274414
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: sqrt
# [[27597   524]
#  [  137    19]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.52      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9828481599981084
# Recall Score: 0.9763058315945822
# Precision Score: 0.9897589127317814
# Accuracy: 0.9763058315945822
# Accuracy (Positive): 0.12179487179487179
# Accuracy (Negative): 0.9810461932363714
# Accuracy (Positive)+(Negative) AVG: 0.5514205325156216
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[27588   533]
#  [  137    19]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9827190965927115
# Recall Score: 0.9760582805813912
# Precision Score: 0.9897552938094631
# Accuracy: 0.9760582805813912
# Accuracy (Positive): 0.12179487179487179
# Accuracy (Negative): 0.9807972689449166
# Accuracy (Positive)+(Negative) AVG: 0.5512960703698941
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: sqrt
# [[27581   540]
#  [  137    19]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9826084904391501
# Recall Score: 0.9758460939986562
# Precision Score: 0.9897522382735033
# Accuracy: 0.9758460939986562
# Accuracy (Positive): 0.12179487179487179
# Accuracy (Negative): 0.9805839052665268
# Accuracy (Positive)+(Negative) AVG: 0.5511893885306993
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[27575   546]
#  [  137    19]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9821846493047185
# Recall Score: 0.9750327120981717
# Precision Score: 0.9897408975852944
# Accuracy: 0.9750327120981717
# Accuracy (Positive): 0.12179487179487179
# Accuracy (Negative): 0.9797660111660325
# Accuracy (Positive)+(Negative) AVG: 0.5507804414804521
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: log2
# [[27552   569]
#  [  137    19]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9819451772486114
# Recall Score: 0.9745729745022457
# Precision Score: 0.9897347303202669
# Accuracy: 0.9745729745022457
# Accuracy (Positive): 0.12179487179487179
# Accuracy (Negative): 0.9793037231961879
# Accuracy (Positive)+(Negative) AVG: 0.5505492974955298
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[27539   582]
#  [  137    19]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.97     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.97      0.98     28277
#
# __________________________________
# F1 Score: 0.983128567631663
# Recall Score: 0.9768716624818757
# Precision Score: 0.9897223244645179
# Accuracy: 0.9768716624818757
# Accuracy (Positive): 0.11538461538461539
# Accuracy (Negative): 0.9816507236584758
# Accuracy (Positive)+(Negative) AVG: 0.5485176695215456
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: log2
# [[27605   516]
#  [  138    18]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9826680451793961
# Recall Score: 0.9759875517204796
# Precision Score: 0.9897095460619654
# Accuracy: 0.9759875517204796
# Accuracy (Positive): 0.11538461538461539
# Accuracy (Negative): 0.9807617083318516
# Accuracy (Positive)+(Negative) AVG: 0.5480731618582335
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt
# [[27580   541]
#  [  138    18]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9826496305097515
# Recall Score: 0.9759521872900236
# Precision Score: 0.9897090502037392
# Accuracy: 0.9759521872900236
# Accuracy (Positive): 0.11538461538461539
# Accuracy (Negative): 0.9807261477187866
# Accuracy (Positive)+(Negative) AVG: 0.548055381551701
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: log2
# [[27579   542]
#  [  138    18]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9825575636175956
# Recall Score: 0.9757753651377444
# Precision Score: 0.9897065875628946
# Accuracy: 0.9757753651377444
# Accuracy (Positive): 0.11538461538461539
# Accuracy (Negative): 0.9805483446534619
# Accuracy (Positive)+(Negative) AVG: 0.5479664800190386
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 1
# Max Features: sqrt
# [[27574   547]
#  [  138    18]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9822077992044853
# Recall Score: 0.9751034409590833
# Precision Score: 0.9896974716494589
# Accuracy: 0.9751034409590833
# Accuracy (Positive): 0.11538461538461539
# Accuracy (Negative): 0.9798726930052274
# Accuracy (Positive)+(Negative) AVG: 0.5476286541949213
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[27555   566]
#  [  138    18]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     28121
#            1       0.03      0.12      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9829849547355716
# Recall Score: 0.9766241114686848
# Precision Score: 0.9896736196281416
# Accuracy: 0.9766241114686848
# Accuracy (Positive): 0.10897435897435898
# Accuracy (Negative): 0.9814373599800861
# Accuracy (Positive)+(Negative) AVG: 0.5452058594772226
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: sqrt
# [[27599   522]
#  [  139    17]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     28121
#            1       0.03      0.11      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.55      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9824330726401829
# Recall Score: 0.9755631785550094
# Precision Score: 0.9896590498260889
# Accuracy: 0.9755631785550094
# Accuracy (Positive): 0.10897435897435898
# Accuracy (Negative): 0.980370541588137
# Accuracy (Positive)+(Negative) AVG: 0.544672450281248
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: log2
# [[27569   552]
#  [  139    17]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     28121
#            1       0.03      0.11      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.54      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9822859603133481
# Recall Score: 0.9752802631113626
# Precision Score: 0.9896553236869917
# Accuracy: 0.9752802631113626
# Accuracy (Positive): 0.10897435897435898
# Accuracy (Negative): 0.9800860566836173
# Accuracy (Positive)+(Negative) AVG: 0.5445302078289881
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: log2
# [[27561   560]
#  [  139    17]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     28121
#            1       0.03      0.11      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.54      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9821940251927871
# Recall Score: 0.9751034409590833
# Precision Score: 0.989653026331154
# Accuracy: 0.9751034409590833
# Accuracy (Positive): 0.10897435897435898
# Accuracy (Negative): 0.9799082536182924
# Accuracy (Positive)+(Negative) AVG: 0.5444413062963257
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: log2
# [[27556   565]
#  [  139    17]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     28121
#            1       0.03      0.11      0.05       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.54      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9824924528735334
# Recall Score: 0.9757046362768328
# Precision Score: 0.9896162036977982
# Accuracy: 0.9757046362768328
# Accuracy (Positive): 0.10256410256410256
# Accuracy (Negative): 0.9805483446534619
# Accuracy (Positive)+(Negative) AVG: 0.5415562236087822
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 1
# Max Features: log2
# [[27574   547]
#  [  140    16]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     28121
#            1       0.03      0.10      0.04       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.54      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9826800704255224
# Recall Score: 0.976093645011847
# Precision Score: 0.989576367325448
# Accuracy: 0.976093645011847
# Accuracy (Positive): 0.09615384615384616
# Accuracy (Negative): 0.9809750720102415
# Accuracy (Positive)+(Negative) AVG: 0.5385644590820439
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 1
# Max Features: log2
# [[27586   535]
#  [  141    15]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     28121
#            1       0.03      0.10      0.04       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.54      0.52     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________
# F1 Score: 0.9826471611993107
# Recall Score: 0.9760582805813912
# Precision Score: 0.989530909200296
# Accuracy: 0.9760582805813912
# Accuracy (Positive): 0.08974358974358974
# Accuracy (Negative): 0.9809750720102415
# Accuracy (Positive)+(Negative) AVG: 0.5353593308769156
# SelectKBest N features: 14
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: sqrt
# [[27586   535]
#  [  142    14]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     28121
#            1       0.03      0.09      0.04       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.54      0.51     28277
# weighted avg       0.99      0.98      0.98     28277
#
# __________________________________

# %% [markdown]
# Based on the above researching this code will run the model with SelectKBest for 7 features, SMOTETomek resampling technique, and with these Parameters:
# learning_rate=0.1
# n_estimators=50
# max_depth=5
# min_samples_split=2
# min_samples_leaf=10
# subsample=0.8
# max_features='sqrt'

# %%
#import Data
df = pd.read_csv("original_data.csv")
x = df.drop(['TARGET'], axis=1)
y = df['TARGET']

#split data to test/train samples
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42, stratify=y)
select = SelectKBest(score_func=f_regression, k=7)
X_train_selected = select.fit_transform(X_train,y_train)

#get the names of features for later deployment
selected_indices = select.get_support(indices=True)
selected_columns = x.columns[selected_indices]

X_test_selected = select.transform(X_test)


#SMOTETomek resampling
resampler = SMOTETomek()
X_train_resampled, y_train_resampled = resampler.fit_resample(X_train_selected, y_train)

#GradientBoostingClassifier model implemntation
model = GradientBoostingClassifier(learning_rate=0.1, n_estimators=50, max_depth=5,
                                   min_samples_split=2, min_samples_leaf=10,
                                   subsample=0.8, max_features='sqrt')
selected_model = model.fit(X_train_resampled, y_train_resampled)

# Convert selected_columns to a DataFrame
selected_columns_df = pd.DataFrame(selected_columns, columns=['Selected Columns'])

# Save the selected_columns DataFrame to a CSV file later deployment
selected_columns_df.to_csv('selected_columns.csv',header=False, index=False)

# Save the trained model later deployment
pickle.dump(selected_model, open('trained_model.pkl','wb'))

y_pred = selected_model.predict(X_test_selected)

#metrics calculations
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)
print("Confusion Matrix:")
print(confusion)
print("\nClassification Report:")
print(report)
print("\nSelected Columns:")
print(selected_columns)
accuracy_positive = accuracy_score(y_test[y_test == 1], y_pred[y_test == 1])
accuracy_negative = accuracy_score(y_test[y_test == 0], y_pred[y_test == 0])
avg_accPN = (accuracy_positive + accuracy_negative) / 2
print("\naccuracy_positive:",accuracy_positive)
print("\naccuracy_negative:",accuracy_negative)
print("\naccuracy_Avg:",avg_accPN)
# Out:
# Confusion Matrix:
# [[23266  4855]
#  [   27   129]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91     28121
#            1       0.03      0.83      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
#
# Selected Columns:
# Index(['CUSTOMER_WITH_ORANGE_MONTHS', 'COMMITMENT', 'COMMITMENT_FG',
#        'MIGRATION_FLAG', 'Disconnection_TOTAL_MIN_day', 'East_Amman',
#        'West_Amman'],
#       dtype='object')
#
# accuracy_positive: 0.8269230769230769
#
# accuracy_negative: 0.8273532235695743
#
# accuracy_Avg: 0.8271381502463255

# %% [markdown]
# Small deployment for best model and parameters we picked

# %%
selected_columns = [] 
selected_model = None 
input_data = pd.DataFrame()  
predicted_data = pd.DataFrame()  
feature_names = []

warnings.filterwarnings("ignore")

#Function to load the model
def load_model():
    model_file = filedialog.askopenfilename(filetypes=[("Model File", "*.pkl")])
    if model_file:
        global selected_model, selected_columns
        selected_model = joblib.load(model_file)
        status_label.config(text="Model loaded successfully!")
        #import selected features from csv file
        selected_columns = pd.read_csv('selected_columns.csv', header=None).values.flatten().tolist()

#Function to enter data manually and its 2nd window
def enter_data_manually():
    global input_data, selected_columns
    input_data = pd.DataFrame(columns=selected_columns)

    def submit_data():
        values = []
        for entry in data_entries:
            values.append(entry.get())
        input_data.loc[len(input_data)] = values
        status_label.config(text="Data entered successfully!")
        clear_entries()
    #Define finction to clear data
    def clear_entries():
        for entry in data_entries:
            entry.delete(0, tk.END)

    # Create a new window for entering data manually
    manual_entry_window = tk.Toplevel(window)
    manual_entry_window.title("Manual Data Entry")

    # Create data entry labels and entry fields for selected columns
    data_entries = []
    for i, column in enumerate(selected_columns):
        tk.Label(manual_entry_window, text=column).grid(row=i, column=0)
        entry = tk.Entry(manual_entry_window)
        entry.grid(row=i, column=1)
        data_entries.append(entry)

    # Create submit and clear buttons
    submit_button = tk.Button(manual_entry_window, text="Submit", command=submit_data)
    submit_button.grid(row=len(selected_columns), column=0, pady=10)
    clear_button = tk.Button(manual_entry_window, text="Clear", command=clear_entries)
    clear_button.grid(row=len(selected_columns), column=1, pady=10)


# Function to predict using the loaded model
def predict():
    global predicted_data
    try:
        input_data_selected = input_data[selected_columns]  # Select only the desired columns
        predicted_data = input_data.copy()
        predicted_data['Prediction'] = selected_model.predict(input_data_selected)
        status_label.config(text="Prediction complete!")
        prediction_label.config(text="Prediction: {}".format(predicted_data['Prediction'].values[0]))
    except Exception as e:
        status_label.config(text="Prediction error: {}".format(str(e)))
        prediction_label.config(text="")

# Function to export the predicted data
def export_data():
    export_file = filedialog.asksaveasfilename(defaultextension=".csv", filetypes=[("CSV File", "*.csv")])
    if export_file:
        predicted_data.to_csv(export_file, index=False)
        status_label.config(text="Data exported successfully!")

def import_data():
    data_file = filedialog.askopenfilename(filetypes=[("CSV Files", "*.csv")])
    if data_file:
        global input_data, selected_columns
        input_data = pd.read_csv(data_file)
        status_label.config(text="Data imported successfully!")

# Create the main window
window = tk.Tk()
window.title("Model Deployment")

# Create buttons and labels
load_model_button = tk.Button(window, text="Load Model", command=load_model)
load_model_button.pack()

import_data_button = tk.Button(window, text="Import Data", command=import_data)
import_data_button.pack()

enter_data_button = tk.Button(window, text="Enter Data Manually", command=enter_data_manually)
enter_data_button.pack()

predict_button = tk.Button(window, text="Predict", command=predict)
predict_button.pack()

export_data_button = tk.Button(window, text="Export Predicted Data", command=export_data)
export_data_button.pack()

status_label = tk.Label(window, text="")
status_label.pack()

prediction_label = tk.Label(window, text="")
prediction_label.pack()

# Run the main event loop
window.mainloop()
