# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import RandomUnderSampler
from sklearn.feature_selection import SelectKBest
import warnings
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import xgboost as xgb
from sklearn.feature_selection import f_regression
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report

warnings.filterwarnings("ignore")
resampling_techniques = [RandomOverSampler, SMOTE, SMOTETomek, RandomUnderSampler]
models = [RandomForestClassifier(class_weight='balanced'), xgb.XGBClassifier(), GradientBoostingClassifier(), DecisionTreeClassifier()]
df = pd.read_csv('original_data.csv')
df['CUSTOMER_AGE'] = df['CUSTOMER_AGE'].apply(lambda age: age * 12)
x = df.drop(['TARGET'], axis=1)
y = df['TARGET']
progress_bar = tqdm(total=224)
# Initialize results for storing the models, hyperparameters, and evaluation scores
results = []
for p in range(3, 17):
    select = SelectKBest(score_func=f_regression, k=p)
    z = select.fit_transform(x, y) 
    X_train, X_test, y_train, y_test = train_test_split(z, y, test_size=0.30, random_state=42, stratify=y)

    for resampling in resampling_techniques:
        resampler = resampling()
        X_train_resampled, y_train_resampled = resampler.fit_resample(X_train, y_train)

        for model in models:
            best_model = model
            best_model.fit(X_train_resampled, y_train_resampled)
            y_pred = best_model.predict(X_test)
            f1 = f1_score(y_test, y_pred, average='weighted')
            recall = recall_score(y_test, y_pred).mean()
            precision = precision_score(y_test, y_pred, average='weighted')
            accuracy = accuracy_score(y_test, y_pred)
            progress_bar.update(1)

            # Calculate accuracy for positive and negative classes
            accuracy_positive = accuracy_score(y_test[y_test == 1],y_pred[y_test == 1])
            accuracy_negative = accuracy_score(y_test[y_test == 0],y_pred[y_test == 0])
            avg_accPN = (accuracy_positive+accuracy_negative) / 2
            confusion = confusion_matrix(y_test,y_pred)
            report = classification_report(y_test,y_pred)


            result = {
                'Undersampling Technique': resampling.__name__,
                'Model': type(best_model).__name__,
                'F1 Score': f1,
                'Recall Score': recall,
                'Precision Score': precision,
                'Accuracy': accuracy,
                'Accuracy (Positive)': accuracy_positive,
                'Accuracy (Negative)': accuracy_negative,
                'Accuracy (Positive)+(Negative) AVG': avg_accPN,
                'SelectKBest N features': p,
                'confusion_matrix': confusion,
                'classification_report': report
            }
            results.append(result)

progress_bar.close()
# Sort the results based on the average accuracy
results = sorted(results, key=lambda x: x['Accuracy (Positive)+(Negative) AVG'],reverse=True)

# Print the sorted results
for result in results:
    print("Undersampling Technique:", result['Undersampling Technique'])
    print("Model:", result['Model'])
    print("F1 Score:", result['F1 Score'])
    print("Recall Score:", result['Recall Score'])
    print("Precision Score:", result['Precision Score'])
    print("Accuracy:", result['Accuracy'])
    print("Accuracy (Positive):", result['Accuracy (Positive)'])
    print("Accuracy (Negative):", result['Accuracy (Negative)'])
    print("Accuracy (Positive)+(Negative) AVG:", result['Accuracy (Positive)+(Negative) AVG'])
    print("SelectKBest N features:", result['SelectKBest N features'])
    print("confusion_matrix", result['confusion_matrix'])
    print("classification_report", result['classification_report'])
    print('__________________________________')
# Out:
# 100%|██████████| 224/224 [14:56<00:00,  4.00s/it]
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.896270968193134
# Recall Score: 0.8589743589743589
# Precision Score: 0.9936783387366669
# Accuracy: 0.8206316087279414
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8204189040219053
# Accuracy (Positive)+(Negative) AVG: 0.8396966314981321
# SelectKBest N features: 14
# confusion_matrix [[23071  5050]
#  [   22   134]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.8977469554257976
# Recall Score: 0.8525641025641025
# Precision Score: 0.9936392116196578
# Accuracy: 0.823071754429395
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8229081469364532
# Accuracy (Positive)+(Negative) AVG: 0.8377361247502779
# SelectKBest N features: 3
# confusion_matrix [[23141  4980]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.8972560166878684
# Recall Score: 0.8525641025641025
# Precision Score: 0.9936375875507393
# Accuracy: 0.8222583725289104
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8220902528359589
# Accuracy (Positive)+(Negative) AVG: 0.8373271777000307
# SelectKBest N features: 3
# confusion_matrix [[23118  5003]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.8956307282431205
# Recall Score: 0.8525641025641025
# Precision Score: 0.9936322474780086
# Accuracy: 0.819570675814266
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8193876462430212
# Accuracy (Positive)+(Negative) AVG: 0.8359758744035619
# SelectKBest N features: 4
# confusion_matrix [[23042  5079]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8952022386200229
# Recall Score: 0.8525641025641025
# Precision Score: 0.9936308486841515
# Accuracy: 0.8188633872051491
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8186764339817219
# Accuracy (Positive)+(Negative) AVG: 0.8356202682729121
# SelectKBest N features: 15
# confusion_matrix [[23022  5099]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.893097906479653
# Recall Score: 0.8525641025641025
# Precision Score: 0.9936240312866882
# Accuracy: 0.815397673020476
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.8151914939013548
# Accuracy (Positive)+(Negative) AVG: 0.8338777982327287
# SelectKBest N features: 4
# confusion_matrix [[22924  5197]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.82      0.89     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.8964244462784677
# Recall Score: 0.8461538461538461
# Precision Score: 0.99359087257349
# Accuracy: 0.8208791597411323
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8207389495394901
# Accuracy (Positive)+(Negative) AVG: 0.8334463978466682
# SelectKBest N features: 5
# confusion_matrix [[23080  5041]
#  [   24   132]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9005611292142045
# Recall Score: 0.8333333333333334
# Precision Score: 0.9935176793351049
# Accuracy: 0.8277398592495668
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.8277088297002241
# Accuracy (Positive)+(Negative) AVG: 0.8305210815167787
# SelectKBest N features: 6
# confusion_matrix [[23276  4845]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91     28121
#            1       0.03      0.83      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.8962766111370819
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935463945021461
# Accuracy: 0.8206316087279414
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8205255858611002
# Accuracy (Positive)+(Negative) AVG: 0.830134587802345
# SelectKBest N features: 5
# confusion_matrix [[23074  5047]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.84      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9013475038614137
# Recall Score: 0.8269230769230769
# Precision Score: 0.9934769480261243
# Accuracy: 0.8290483431764332
# Accuracy (Positive): 0.8269230769230769
# Accuracy (Negative): 0.8290601329966929
# Accuracy (Positive)+(Negative) AVG: 0.8279916049598849
# SelectKBest N features: 7
# confusion_matrix [[23314  4807]
#  [   27   129]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91     28121
#            1       0.03      0.83      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.83      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8891278197801549
# Recall Score: 0.8461538461538461
# Precision Score: 0.9935668312179756
# Accuracy: 0.8088906178166001
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8086839017104654
# Accuracy (Positive)+(Negative) AVG: 0.8274188739321557
# SelectKBest N features: 13
# confusion_matrix [[22741  5380]
#  [   24   132]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8959147732155507
# Recall Score: 0.8333333333333334
# Precision Score: 0.9935011485264618
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.8199566160520607
# Accuracy (Positive)+(Negative) AVG: 0.826644974692697
# SelectKBest N features: 16
# confusion_matrix [[23058  5063]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.83      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8867179488555837
# Recall Score: 0.8461538461538461
# Precision Score: 0.9935590860854209
# Accuracy: 0.804965166036001
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8047366736602539
# Accuracy (Positive)+(Negative) AVG: 0.8254452599070501
# SelectKBest N features: 5
# confusion_matrix [[22630  5491]
#  [   24   132]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.80     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.80      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8904500028012529
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935266755134131
# Accuracy: 0.8110478480744068
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8108886597204936
# Accuracy (Positive)+(Negative) AVG: 0.8253161247320417
# SelectKBest N features: 9
# confusion_matrix [[22803  5318]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     28121
#            1       0.02      0.84      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8861737596602922
# Recall Score: 0.8461538461538461
# Precision Score: 0.9935573488765936
# Accuracy: 0.8040810552746048
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.8038476583336297
# Accuracy (Positive)+(Negative) AVG: 0.8250007522437379
# SelectKBest N features: 6
# confusion_matrix [[22605  5516]
#  [   24   132]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     28121
#            1       0.02      0.85      0.05       156
#
#     accuracy                           0.80     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.80      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8898012639651881
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935245161395665
# Accuracy: 0.8099869151607313
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8098218413285445
# Accuracy (Positive)+(Negative) AVG: 0.8247827155360672
# SelectKBest N features: 11
# confusion_matrix [[22773  5348]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.84      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8879156816294111
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935182768138565
# Accuracy: 0.8069102097110726
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.8067280679918922
# Accuracy (Positive)+(Negative) AVG: 0.823235828867741
# SelectKBest N features: 8
# confusion_matrix [[22686  5435]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.84      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8742608483562023
# Recall Score: 0.8589743589743589
# Precision Score: 0.9936118183171331
# Accuracy: 0.7849488983979913
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.7845382454393514
# Accuracy (Positive)+(Negative) AVG: 0.8217563022068551
# SelectKBest N features: 15
# confusion_matrix [[22062  6059]
#  [   22   134]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.86      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8780990331495094
# Recall Score: 0.8525641025641025
# Precision Score: 0.9935774838775184
# Accuracy: 0.7910669448668529
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.790725792112656
# Accuracy (Positive)+(Negative) AVG: 0.8216449473383793
# SelectKBest N features: 16
# confusion_matrix [[22236  5885]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88     28121
#            1       0.02      0.85      0.04       156
#
#     accuracy                           0.79     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.79      0.88     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8930631445455047
# Recall Score: 0.8269230769230769
# Precision Score: 0.9934469943569225
# Accuracy: 0.8153269441595643
# Accuracy (Positive): 0.8269230769230769
# Accuracy (Negative): 0.8152626151274848
# Accuracy (Positive)+(Negative) AVG: 0.8210928460252809
# SelectKBest N features: 12
# confusion_matrix [[22926  5195]
#  [   27   129]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.02      0.83      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.82      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8851735962851601
# Recall Score: 0.8397435897435898
# Precision Score: 0.9935092952273017
# Accuracy: 0.8024542914736358
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.802247430745706
# Accuracy (Positive)+(Negative) AVG: 0.8209955102446479
# SelectKBest N features: 10
# confusion_matrix [[22560  5561]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     28121
#            1       0.02      0.84      0.04       156
#
#     accuracy                           0.80     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.80      0.89     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8768826120962584
# Recall Score: 0.8525641025641025
# Precision Score: 0.9935738343004771
# Accuracy: 0.7891219011917813
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.7887699583940827
# Accuracy (Positive)+(Negative) AVG: 0.8206670304790926
# SelectKBest N features: 11
# confusion_matrix [[22181  5940]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88     28121
#            1       0.02      0.85      0.04       156
#
#     accuracy                           0.79     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.79      0.88     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8886339672778976
# Recall Score: 0.8333333333333334
# Precision Score: 0.9934760642573365
# Accuracy: 0.8080772359161156
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.8079371288361011
# Accuracy (Positive)+(Negative) AVG: 0.8206352310847173
# SelectKBest N features: 7
# confusion_matrix [[22720  5401]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.89     28121
#            1       0.02      0.83      0.05       156
#
#     accuracy                           0.81     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.81      0.89     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9060802946247013
# Recall Score: 0.8012820512820513
# Precision Score: 0.9933219400148431
# Accuracy: 0.836969975598543
# Accuracy (Positive): 0.8012820512820513
# Accuracy (Negative): 0.8371679527755058
# Accuracy (Positive)+(Negative) AVG: 0.8192250020287786
# SelectKBest N features: 6
# confusion_matrix [[23542  4579]
#  [   31   125]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91     28121
#            1       0.03      0.80      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8749753161484405
# Recall Score: 0.8525641025641025
# Precision Score: 0.9935681418438737
# Accuracy: 0.7860805601725784
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.7857117456704954
# Accuracy (Positive)+(Negative) AVG: 0.8191379241172989
# SelectKBest N features: 12
# confusion_matrix [[22095  6026]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88     28121
#            1       0.02      0.85      0.04       156
#
#     accuracy                           0.79     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.79      0.87     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8867228110329766
# Recall Score: 0.8333333333333334
# Precision Score: 0.9934696185553472
# Accuracy: 0.804965166036001
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.8048077948863839
# Accuracy (Positive)+(Negative) AVG: 0.8190705641098586
# SelectKBest N features: 4
# confusion_matrix [[22632  5489]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     28121
#            1       0.02      0.83      0.05       156
#
#     accuracy                           0.80     28277
#    macro avg       0.51      0.82      0.47     28277
# weighted avg       0.99      0.80      0.89     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9095794169906796
# Recall Score: 0.7948717948717948
# Precision Score: 0.9932936088068754
# Accuracy: 0.8428758354846695
# Accuracy (Positive): 0.7948717948717948
# Accuracy (Negative): 0.8431421357704206
# Accuracy (Positive)+(Negative) AVG: 0.8190069653211077
# SelectKBest N features: 10
# confusion_matrix [[23710  4411]
#  [   32   124]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91     28121
#            1       0.03      0.79      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9089317614813517
# Recall Score: 0.7948717948717948
# Precision Score: 0.9932908322268355
# Accuracy: 0.8417795381405383
# Accuracy (Positive): 0.7948717948717948
# Accuracy (Negative): 0.8420397567654067
# Accuracy (Positive)+(Negative) AVG: 0.8184557758186007
# SelectKBest N features: 10
# confusion_matrix [[23679  4442]
#  [   32   124]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91     28121
#            1       0.03      0.79      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9089108569261645
# Recall Score: 0.7948717948717948
# Precision Score: 0.9932907428149247
# Accuracy: 0.8417441737100824
# Accuracy (Positive): 0.7948717948717948
# Accuracy (Negative): 0.8420041961523417
# Accuracy (Positive)+(Negative) AVG: 0.8184379955120682
# SelectKBest N features: 7
# confusion_matrix [[23678  4443]
#  [   32   124]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91     28121
#            1       0.03      0.79      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8996543770006277
# Recall Score: 0.8076923076923077
# Precision Score: 0.9933396295117538
# Accuracy: 0.8262191887399654
# Accuracy (Positive): 0.8076923076923077
# Accuracy (Negative): 0.8263219657906903
# Accuracy (Positive)+(Negative) AVG: 0.817007136741499
# SelectKBest N features: 3
# confusion_matrix [[23237  4884]
#  [   30   126]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.90     28121
#            1       0.03      0.81      0.05       156
#
#     accuracy                           0.83     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.83      0.90     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9108109709715062
# Recall Score: 0.7884615384615384
# Precision Score: 0.9932560876806298
# Accuracy: 0.8449623368815645
# Accuracy (Positive): 0.7884615384615384
# Accuracy (Negative): 0.8452757725543188
# Accuracy (Positive)+(Negative) AVG: 0.8168686555079286
# SelectKBest N features: 9
# confusion_matrix [[23770  4351]
#  [   33   123]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92     28121
#            1       0.03      0.79      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9107067960227554
# Recall Score: 0.7884615384615384
# Precision Score: 0.9932556286942064
# Accuracy: 0.8447855147292853
# Accuracy (Positive): 0.7884615384615384
# Accuracy (Negative): 0.845097969488994
# Accuracy (Positive)+(Negative) AVG: 0.8167797539752661
# SelectKBest N features: 9
# confusion_matrix [[23765  4356]
#  [   33   123]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92     28121
#            1       0.03      0.79      0.05       156
#
#     accuracy                           0.84     28277
#    macro avg       0.51      0.82      0.48     28277
# weighted avg       0.99      0.84      0.91     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8711413555674694
# Recall Score: 0.8525641025641025
# Precision Score: 0.9935568002553206
# Accuracy: 0.7799978781341727
# Accuracy (Positive): 0.8525641025641025
# Accuracy (Negative): 0.7795953202233207
# Accuracy (Positive)+(Negative) AVG: 0.8160797113937116
# SelectKBest N features: 10
# confusion_matrix [[21923  6198]
#  [   23   133]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.85      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.82      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9121435987520006
# Recall Score: 0.782051282051282
# Precision Score: 0.9932192551564172
# Accuracy: 0.8472256604307388
# Accuracy (Positive): 0.782051282051282
# Accuracy (Negative): 0.8475872124035418
# Accuracy (Positive)+(Negative) AVG: 0.814819247227412
# SelectKBest N features: 8
# confusion_matrix [[23835  4286]
#  [   34   122]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92     28121
#            1       0.03      0.78      0.05       156
#
#     accuracy                           0.85     28277
#    macro avg       0.51      0.81      0.49     28277
# weighted avg       0.99      0.85      0.91     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9120188904633868
# Recall Score: 0.782051282051282
# Precision Score: 0.993218691424679
# Accuracy: 0.8470134738480036
# Accuracy (Positive): 0.782051282051282
# Accuracy (Negative): 0.847373848725152
# Accuracy (Positive)+(Negative) AVG: 0.814712565388217
# SelectKBest N features: 8
# confusion_matrix [[23829  4292]
#  [   34   122]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92     28121
#            1       0.03      0.78      0.05       156
#
#     accuracy                           0.85     28277
#    macro avg       0.51      0.81      0.49     28277
# weighted avg       0.99      0.85      0.91     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: RandomForestClassifier
# F1 Score: 0.8731539243478499
# Recall Score: 0.8461538461538461
# Precision Score: 0.9935168501378703
# Accuracy: 0.7831806768751989
# Accuracy (Positive): 0.8461538461538461
# Accuracy (Negative): 0.7828313360122329
# Accuracy (Positive)+(Negative) AVG: 0.8144925910830395
# SelectKBest N features: 16
# confusion_matrix [[22014  6107]
#  [   24   132]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.85      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.81      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8804444122427593
# Recall Score: 0.8333333333333334
# Precision Score: 0.9934487759384145
# Accuracy: 0.7948155744951727
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.7946018989367377
# Accuracy (Positive)+(Negative) AVG: 0.8139676161350355
# SelectKBest N features: 4
# confusion_matrix [[22345  5776]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.89     28121
#            1       0.02      0.83      0.04       156
#
#     accuracy                           0.79     28277
#    macro avg       0.51      0.81      0.46     28277
# weighted avg       0.99      0.79      0.88     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.917872096019218
# Recall Score: 0.7692307692307693
# Precision Score: 0.9931611019361432
# Accuracy: 0.8570216076670085
# Accuracy (Positive): 0.7692307692307693
# Accuracy (Negative): 0.8575086234486683
# Accuracy (Positive)+(Negative) AVG: 0.8133696963397188
# SelectKBest N features: 11
# confusion_matrix [[24114  4007]
#  [   36   120]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92     28121
#            1       0.03      0.77      0.06       156
#
#     accuracy                           0.86     28277
#    macro avg       0.51      0.81      0.49     28277
# weighted avg       0.99      0.86      0.92     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8734244664590917
# Recall Score: 0.8397435897435898
# Precision Score: 0.9934718167857755
# Accuracy: 0.783605050040669
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.7832936239820775
# Accuracy (Positive)+(Negative) AVG: 0.8115186068628336
# SelectKBest N features: 5
# confusion_matrix [[22027  6094]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.84      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.81      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9187362458978514
# Recall Score: 0.7564102564102564
# Precision Score: 0.9930808224751103
# Accuracy: 0.8585069137461541
# Accuracy (Positive): 0.7564102564102564
# Accuracy (Negative): 0.8590732904235269
# Accuracy (Positive)+(Negative) AVG: 0.8077417734168917
# SelectKBest N features: 11
# confusion_matrix [[24158  3963]
#  [   38   118]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92     28121
#            1       0.03      0.76      0.06       156
#
#     accuracy                           0.86     28277
#    macro avg       0.51      0.81      0.49     28277
# weighted avg       0.99      0.86      0.92     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8662967878846817
# Recall Score: 0.8397435897435898
# Precision Score: 0.9934496783278777
# Accuracy: 0.7723591611557096
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.7719853490274172
# Accuracy (Positive)+(Negative) AVG: 0.8058644693855035
# SelectKBest N features: 14
# confusion_matrix [[21709  6412]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.77      0.87     28121
#            1       0.02      0.84      0.04       156
#
#     accuracy                           0.77     28277
#    macro avg       0.51      0.81      0.45     28277
# weighted avg       0.99      0.77      0.87     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9194754202374624
# Recall Score: 0.75
# Precision Score: 0.993042369574463
# Accuracy: 0.8597800332425646
# Accuracy (Positive): 0.75
# Accuracy (Negative): 0.8603890331069307
# Accuracy (Positive)+(Negative) AVG: 0.8051945165534653
# SelectKBest N features: 12
# confusion_matrix [[24195  3926]
#  [   39   117]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92     28121
#            1       0.03      0.75      0.06       156
#
#     accuracy                           0.86     28277
#    macro avg       0.51      0.81      0.49     28277
# weighted avg       0.99      0.86      0.92     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8730297885700138
# Recall Score: 0.8269230769230769
# Precision Score: 0.9933788198758571
# Accuracy: 0.7829684902924638
# Accuracy (Positive): 0.8269230769230769
# Accuracy (Negative): 0.7827246541730379
# Accuracy (Positive)+(Negative) AVG: 0.8048238655480574
# SelectKBest N features: 13
# confusion_matrix [[22011  6110]
#  [   27   129]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.83      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.80      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: GradientBoostingClassifier
# F1 Score: 0.9225636627288761
# Recall Score: 0.7435897435897436
# Precision Score: 0.9930164923242263
# Accuracy: 0.8651200622413976
# Accuracy (Positive): 0.7435897435897436
# Accuracy (Negative): 0.8657942462928061
# Accuracy (Positive)+(Negative) AVG: 0.8046919949412749
# SelectKBest N features: 13
# confusion_matrix [[24347  3774]
#  [   40   116]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93     28121
#            1       0.03      0.74      0.06       156
#
#     accuracy                           0.87     28277
#    macro avg       0.51      0.80      0.49     28277
# weighted avg       0.99      0.87      0.92     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8835262120404369
# Recall Score: 0.8076923076923077
# Precision Score: 0.9932790131233623
# Accuracy: 0.7997665947589914
# Accuracy (Positive): 0.8076923076923077
# Accuracy (Negative): 0.7997226272180933
# Accuracy (Positive)+(Negative) AVG: 0.8037074674552005
# SelectKBest N features: 9
# confusion_matrix [[22489  5632]
#  [   30   126]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     28121
#            1       0.02      0.81      0.04       156
#
#     accuracy                           0.80     28277
#    macro avg       0.51      0.80      0.47     28277
# weighted avg       0.99      0.80      0.88     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9176885020686523
# Recall Score: 0.75
# Precision Score: 0.9930332402089019
# Accuracy: 0.8567033277929059
# Accuracy (Positive): 0.75
# Accuracy (Negative): 0.8572952597702784
# Accuracy (Positive)+(Negative) AVG: 0.8036476298851392
# SelectKBest N features: 12
# confusion_matrix [[24108  4013]
#  [   39   117]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92     28121
#            1       0.03      0.75      0.05       156
#
#     accuracy                           0.86     28277
#    macro avg       0.51      0.80      0.49     28277
# weighted avg       0.99      0.86      0.92     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: RandomForestClassifier
# F1 Score: 0.8709085393578531
# Recall Score: 0.8269230769230769
# Precision Score: 0.9933718340984473
# Accuracy: 0.7796088693991583
# Accuracy (Positive): 0.8269230769230769
# Accuracy (Negative): 0.7793463959318658
# Accuracy (Positive)+(Negative) AVG: 0.8031347364274714
# SelectKBest N features: 14
# confusion_matrix [[21916  6205]
#  [   27   129]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.83      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.80      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8620178171641234
# Recall Score: 0.8397435897435898
# Precision Score: 0.9934365424159274
# Accuracy: 0.7656752837995544
# Accuracy (Positive): 0.8397435897435898
# Accuracy (Negative): 0.7652643931581381
# Accuracy (Positive)+(Negative) AVG: 0.8025039914508639
# SelectKBest N features: 3
# confusion_matrix [[21520  6601]
#  [   25   131]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.77      0.87     28121
#            1       0.02      0.84      0.04       156
#
#     accuracy                           0.77     28277
#    macro avg       0.51      0.80      0.45     28277
# weighted avg       0.99      0.77      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8709118515608272
# Recall Score: 0.8205128205128205
# Precision Score: 0.9933257927717019
# Accuracy: 0.7796088693991583
# Accuracy (Positive): 0.8205128205128205
# Accuracy (Negative): 0.7793819565449308
# Accuracy (Positive)+(Negative) AVG: 0.7999473885288757
# SelectKBest N features: 6
# confusion_matrix [[21917  6204]
#  [   28   128]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.82      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.80      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: GradientBoostingClassifier
# F1 Score: 0.9231346701562694
# Recall Score: 0.7307692307692307
# Precision Score: 0.9929356829010123
# Accuracy: 0.8661102662941613
# Accuracy (Positive): 0.7307692307692307
# Accuracy (Negative): 0.8668610646847552
# Accuracy (Positive)+(Negative) AVG: 0.7988151477269929
# SelectKBest N features: 13
# confusion_matrix [[24377  3744]
#  [   42   114]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93     28121
#            1       0.03      0.73      0.06       156
#
#     accuracy                           0.87     28277
#    macro avg       0.51      0.80      0.49     28277
# weighted avg       0.99      0.87      0.92     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8718985137189282
# Recall Score: 0.8141025641025641
# Precision Score: 0.9932831631463739
# Accuracy: 0.7811649043392156
# Accuracy (Positive): 0.8141025641025641
# Accuracy (Negative): 0.7809821841328545
# Accuracy (Positive)+(Negative) AVG: 0.7975423741177092
# SelectKBest N features: 7
# confusion_matrix [[21962  6159]
#  [   29   127]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.81      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.80      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: GradientBoostingClassifier
# F1 Score: 0.8718091885637742
# Recall Score: 0.8141025641025641
# Precision Score: 0.9932828536796251
# Accuracy: 0.7810234466173922
# Accuracy (Positive): 0.8141025641025641
# Accuracy (Negative): 0.7808399416805946
# Accuracy (Positive)+(Negative) AVG: 0.7974712528915793
# SelectKBest N features: 8
# confusion_matrix [[21958  6163]
#  [   29   127]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.78      0.88     28121
#            1       0.02      0.81      0.04       156
#
#     accuracy                           0.78     28277
#    macro avg       0.51      0.80      0.46     28277
# weighted avg       0.99      0.78      0.87     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: RandomForestClassifier
# F1 Score: 0.8786962118420026
# Recall Score: 0.8012820512820513
# Precision Score: 0.993216141459113
# Accuracy: 0.791986420058705
# Accuracy (Positive): 0.8012820512820513
# Accuracy (Negative): 0.7919348529568649
# Accuracy (Positive)+(Negative) AVG: 0.7966084521194581
# SelectKBest N features: 15
# confusion_matrix [[22270  5851]
#  [   31   125]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.79      0.88     28121
#            1       0.02      0.80      0.04       156
#
#     accuracy                           0.79     28277
#    macro avg       0.51      0.80      0.46     28277
# weighted avg       0.99      0.79      0.88     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8535974139878435
# Recall Score: 0.8333333333333334
# Precision Score: 0.9933633315929941
# Accuracy: 0.7526611733918025
# Accuracy (Positive): 0.8333333333333334
# Accuracy (Negative): 0.7522136481632944
# Accuracy (Positive)+(Negative) AVG: 0.7927734907483139
# SelectKBest N features: 16
# confusion_matrix [[21153  6968]
#  [   26   130]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86     28121
#            1       0.02      0.83      0.04       156
#
#     accuracy                           0.75     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.75      0.85     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8566375143256745
# Recall Score: 0.8269230769230769
# Precision Score: 0.9933254985760563
# Accuracy: 0.7573292782119744
# Accuracy (Positive): 0.8269230769230769
# Accuracy (Negative): 0.7569432097009352
# Accuracy (Positive)+(Negative) AVG: 0.791933143312006
# SelectKBest N features: 5
# confusion_matrix [[21286  6835]
#  [   27   129]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.86     28121
#            1       0.02      0.83      0.04       156
#
#     accuracy                           0.76     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.76      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8644852012889833
# Recall Score: 0.8076923076923077
# Precision Score: 0.9932110378820035
# Accuracy: 0.769494642288786
# Accuracy (Positive): 0.8076923076923077
# Accuracy (Negative): 0.7692827424344796
# Accuracy (Positive)+(Negative) AVG: 0.7884875250633936
# SelectKBest N features: 7
# confusion_matrix [[21633  6488]
#  [   30   126]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.77      0.87     28121
#            1       0.02      0.81      0.04       156
#
#     accuracy                           0.77     28277
#    macro avg       0.51      0.79      0.45     28277
# weighted avg       0.99      0.77      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8599428193852695
# Recall Score: 0.8076923076923077
# Precision Score: 0.9931951197542148
# Accuracy: 0.7624217561976164
# Accuracy (Positive): 0.8076923076923077
# Accuracy (Negative): 0.7621706198214857
# Accuracy (Positive)+(Negative) AVG: 0.7849314637568967
# SelectKBest N features: 11
# confusion_matrix [[21433  6688]
#  [   30   126]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.86     28121
#            1       0.02      0.81      0.04       156
#
#     accuracy                           0.76     28277
#    macro avg       0.51      0.78      0.45     28277
# weighted avg       0.99      0.76      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8621541815575354
# Recall Score: 0.8012820512820513
# Precision Score: 0.9931560624181522
# Accuracy: 0.7658521059518336
# Accuracy (Positive): 0.8012820512820513
# Accuracy (Negative): 0.7656555599018527
# Accuracy (Positive)+(Negative) AVG: 0.7834688055919521
# SelectKBest N features: 9
# confusion_matrix [[21531  6590]
#  [   31   125]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.77      0.87     28121
#            1       0.02      0.80      0.04       156
#
#     accuracy                           0.77     28277
#    macro avg       0.51      0.78      0.45     28277
# weighted avg       0.99      0.77      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8593992338349729
# Recall Score: 0.8012820512820513
# Precision Score: 0.9931461758224408
# Accuracy: 0.7615730098666761
# Accuracy (Positive): 0.8012820512820513
# Accuracy (Negative): 0.7613527257209914
# Accuracy (Positive)+(Negative) AVG: 0.7813173885015214
# SelectKBest N features: 15
# confusion_matrix [[21410  6711]
#  [   31   125]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.86     28121
#            1       0.02      0.80      0.04       156
#
#     accuracy                           0.76     28277
#    macro avg       0.51      0.78      0.45     28277
# weighted avg       0.99      0.76      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8586724013219259
# Recall Score: 0.7948717948717948
# Precision Score: 0.9930964696000402
# Accuracy: 0.760441348092089
# Accuracy (Positive): 0.7948717948717948
# Accuracy (Negative): 0.7602503467159774
# Accuracy (Positive)+(Negative) AVG: 0.777561070793886
# SelectKBest N features: 12
# confusion_matrix [[21379  6742]
#  [   32   124]]
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.76      0.86     28121
#            1       0.02      0.79      0.04       156
#
#     accuracy                           0.76     28277
#    macro avg       0.51      0.78      0.45     28277
# weighted avg       0.99      0.76      0.86     28277
#
# __________________________________
# Undersampling Technique: RandomUnderSampler
# Model: XGBClassifier
# F1 Score: 0.8529727837785293
# Recall Score: 0.8012820512820513
# Precision Score: 0.9931231809614113
# Accuracy: 0.7516709693390388
# Accuracy (Positive): 0.8012820512820513
# Accuracy (Negative): 0.7513957540628
# Accuracy (Positive)+(Negative) AVG: 0.7763389026724257
# SelectKBest N features: 6
# confusion_matrix [[21130  6991]
#  [   31   125]]
# classification_report               precision    recall  f1-score   support
#
# ...
#            0       0.99      0.99      0.99     28121
#            1       0.03      0.06      0.04       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.52      0.51     28277
# weighted avg       0.99      0.98      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: RandomForestClassifier
# F1 Score: 0.9889181386125856
# Recall Score: 0.05128205128205128
# Precision Score: 0.989476581409566
# Accuracy: 0.9883651023800262
# Accuracy (Positive): 0.05128205128205128
# Accuracy (Negative): 0.9935635290352406
# Accuracy (Positive)+(Negative) AVG: 0.5224227901586459
# SelectKBest N features: 15
# confusion_matrix [[27940   181]
#  [  148     8]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.04      0.05      0.05       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: RandomForestClassifier
# F1 Score: 0.9887884620147923
# Recall Score: 0.05128205128205128
# Precision Score: 0.9894669352560646
# Accuracy: 0.9881175513668352
# Accuracy (Positive): 0.05128205128205128
# Accuracy (Negative): 0.9933146047437857
# Accuracy (Positive)+(Negative) AVG: 0.5222983280129185
# SelectKBest N features: 14
# confusion_matrix [[27933   188]
#  [  148     8]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.04      0.05      0.05       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: RandomForestClassifier
# F1 Score: 0.9884926686470238
# Recall Score: 0.05128205128205128
# Precision Score: 0.9894469525764483
# Accuracy: 0.9875517204795417
# Accuracy (Positive): 0.05128205128205128
# Accuracy (Negative): 0.9927456349347463
# Accuracy (Positive)+(Negative) AVG: 0.5220138431083988
# SelectKBest N features: 15
# confusion_matrix [[27917   204]
#  [  148     8]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.04      0.05      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: RandomForestClassifier
# F1 Score: 0.9884272860825185
# Recall Score: 0.04487179487179487
# Precision Score: 0.989385494698155
# Accuracy: 0.98748099161863
# Accuracy (Positive): 0.04487179487179487
# Accuracy (Negative): 0.9927100743216813
# Accuracy (Positive)+(Negative) AVG: 0.5187909345967381
# SelectKBest N features: 14
# confusion_matrix [[27916   205]
#  [  149     7]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.03      0.04      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: XGBClassifier
# F1 Score: 0.9874742523806375
# Recall Score: 0.04487179487179487
# Precision Score: 0.9893398138437053
# Accuracy: 0.9856420412349259
# Accuracy (Positive): 0.04487179487179487
# Accuracy (Negative): 0.990860922442303
# Accuracy (Positive)+(Negative) AVG: 0.5178663586570489
# SelectKBest N features: 15
# confusion_matrix [[27864   257]
#  [  149     7]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.03      0.04      0.03       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.52      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: XGBClassifier
# F1 Score: 0.9872001740583328
# Recall Score: 0.04487179487179487
# Precision Score: 0.9893291153950012
# Accuracy: 0.9851115747780882
# Accuracy (Positive): 0.04487179487179487
# Accuracy (Negative): 0.9903275132463284
# Accuracy (Positive)+(Negative) AVG: 0.5175996540590616
# SelectKBest N features: 15
# confusion_matrix [[27849   272]
#  [  149     7]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.03      0.04      0.03       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.52      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: XGBClassifier
# F1 Score: 0.98707236914611
# Recall Score: 0.04487179487179487
# Precision Score: 0.9893244040624077
# Accuracy: 0.9848640237648972
# Accuracy (Positive): 0.04487179487179487
# Accuracy (Negative): 0.9900785889548736
# Accuracy (Positive)+(Negative) AVG: 0.5174751919133342
# SelectKBest N features: 14
# confusion_matrix [[27842   279]
#  [  149     7]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.02      0.04      0.03       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.52      0.51     28277
# weighted avg       0.99      0.98      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: DecisionTreeClassifier
# F1 Score: 0.9897420704812129
# Recall Score: 0.038461538461538464
# Precision Score: 0.989423679884925
# Accuracy: 0.9900625950419069
# Accuracy (Positive): 0.038461538461538464
# Accuracy (Negative): 0.995341559688489
# Accuracy (Positive)+(Negative) AVG: 0.5169015490750137
# SelectKBest N features: 15
# confusion_matrix [[27990   131]
#  [  150     6]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.04      0.04      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: DecisionTreeClassifier
# F1 Score: 0.9896864840574225
# Recall Score: 0.038461538461538464
# Precision Score: 0.9894179372361173
# Accuracy: 0.9899565017505393
# Accuracy (Positive): 0.038461538461538464
# Accuracy (Negative): 0.9952348778492941
# Accuracy (Positive)+(Negative) AVG: 0.5168482081554163
# SelectKBest N features: 14
# confusion_matrix [[27987   134]
#  [  150     6]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     28121
#            1       0.04      0.04      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.52      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: DecisionTreeClassifier
# F1 Score: 0.9881972753230517
# Recall Score: 0.038461538461538464
# Precision Score: 0.9893159732245438
# Accuracy: 0.9870919828836157
# Accuracy (Positive): 0.038461538461538464
# Accuracy (Negative): 0.9923544681910316
# Accuracy (Positive)+(Negative) AVG: 0.515408003326285
# SelectKBest N features: 16
# confusion_matrix [[27906   215]
#  [  150     6]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.03      0.04      0.03       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.52      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: DecisionTreeClassifier
# F1 Score: 0.9881241558720928
# Recall Score: 0.038461538461538464
# Precision Score: 0.9893125523340497
# Accuracy: 0.9869505251617923
# Accuracy (Positive): 0.038461538461538464
# Accuracy (Negative): 0.9922122257387718
# Accuracy (Positive)+(Negative) AVG: 0.5153368821001552
# SelectKBest N features: 16
# confusion_matrix [[27902   219]
#  [  150     6]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.03      0.04      0.03       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.52      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: XGBClassifier
# F1 Score: 0.987030157970631
# Recall Score: 0.038461538461538464
# Precision Score: 0.9892701821831289
# Accuracy: 0.9848286593344414
# Accuracy (Positive): 0.038461538461538464
# Accuracy (Negative): 0.9900785889548736
# Accuracy (Positive)+(Negative) AVG: 0.514270063708206
# SelectKBest N features: 14
# confusion_matrix [[27842   279]
#  [  150     6]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.02      0.04      0.03       156
#
#     accuracy                           0.98     28277
#    macro avg       0.51      0.51      0.51     28277
# weighted avg       0.99      0.98      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: DecisionTreeClassifier
# F1 Score: 0.9893015995966605
# Recall Score: 0.03205128205128205
# Precision Score: 0.989318625845129
# Accuracy: 0.9892845775718782
# Accuracy (Positive): 0.03205128205128205
# Accuracy (Negative): 0.9945947868141247
# Accuracy (Positive)+(Negative) AVG: 0.5133230344327033
# SelectKBest N features: 16
# confusion_matrix [[27969   152]
#  [  151     5]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     28121
#            1       0.03      0.03      0.03       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: RandomForestClassifier
# F1 Score: 0.9912216587536539
# Recall Score: 0.02564102564102564
# Precision Score: 0.9895784863806972
# Accuracy: 0.993033207200198
# Accuracy (Positive): 0.02564102564102564
# Accuracy (Negative): 0.9983997724120763
# Accuracy (Positive)+(Negative) AVG: 0.5120203990265509
# SelectKBest N features: 15
# confusion_matrix [[28076    45]
#  [  152     4]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.08      0.03      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.54      0.51      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: RandomForestClassifier
# F1 Score: 0.9911466919495042
# Recall Score: 0.02564102564102564
# Precision Score: 0.9895437383782253
# Accuracy: 0.9928917494783747
# Accuracy (Positive): 0.02564102564102564
# Accuracy (Negative): 0.9982575299598165
# Accuracy (Positive)+(Negative) AVG: 0.5119492778004211
# SelectKBest N features: 14
# confusion_matrix [[28072    49]
#  [  152     4]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.08      0.03      0.04       156
#
#     accuracy                           0.99     28277
#    macro avg       0.54      0.51      0.52     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: RandomOverSampler
# Model: RandomForestClassifier
# F1 Score: 0.991814488134345
# Recall Score: 0.01282051282051282
# Precision Score: 0.9906419741034472
# Accuracy: 0.9943770555575202
# Accuracy (Positive): 0.01282051282051282
# Accuracy (Negative): 0.9998221969346751
# Accuracy (Positive)+(Negative) AVG: 0.506321354877594
# SelectKBest N features: 16
# confusion_matrix [[28116     5]
#  [  154     2]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.29      0.01      0.02       156
#
#     accuracy                           0.99     28277
#    macro avg       0.64      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: RandomForestClassifier
# F1 Score: 0.9912626051876057
# Recall Score: 0.01282051282051282
# Precision Score: 0.989358184040368
# Accuracy: 0.9933161226438448
# Accuracy (Positive): 0.01282051282051282
# Accuracy (Negative): 0.9987553785427261
# Accuracy (Positive)+(Negative) AVG: 0.5057879456816194
# SelectKBest N features: 16
# confusion_matrix [[28086    35]
#  [  154     2]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.05      0.01      0.02       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: RandomForestClassifier
# F1 Score: 0.9912443114465604
# Recall Score: 0.01282051282051282
# Precision Score: 0.9893501444114347
# Accuracy: 0.993280758213389
# Accuracy (Positive): 0.01282051282051282
# Accuracy (Negative): 0.9987198179296611
# Accuracy (Positive)+(Negative) AVG: 0.505770165375087
# SelectKBest N features: 16
# confusion_matrix [[28085    36]
#  [  154     2]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.05      0.01      0.02       156
#
#     accuracy                           0.99     28277
#    macro avg       0.52      0.51      0.51     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTE
# Model: XGBClassifier
# F1 Score: 0.9909003823283686
# Recall Score: 0.00641025641025641
# Precision Score: 0.9891279529260276
# Accuracy: 0.9927149273260955
# Accuracy (Positive): 0.00641025641025641
# Accuracy (Negative): 0.9981864087336866
# Accuracy (Positive)+(Negative) AVG: 0.5022983325719715
# SelectKBest N features: 16
# confusion_matrix [[28070    51]
#  [  155     1]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.02      0.01      0.01       156
#
#     accuracy                           0.99     28277
#    macro avg       0.51      0.50      0.50     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________
# Undersampling Technique: SMOTETomek
# Model: XGBClassifier
# F1 Score: 0.9908828904218218
# Recall Score: 0.0
# Precision Score: 0.9889874043584551
# Accuracy: 0.9927856561870071
# Accuracy (Positive): 0.0
# Accuracy (Negative): 0.9982930905728815
# Accuracy (Positive)+(Negative) AVG: 0.49914654528644076
# SelectKBest N features: 16
# confusion_matrix [[28073    48]
#  [  156     0]]
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     28121
#            1       0.00      0.00      0.00       156
#
#     accuracy                           0.99     28277
#    macro avg       0.50      0.50      0.50     28277
# weighted avg       0.99      0.99      0.99     28277
#
# __________________________________

# %% [markdown]
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.combine import SMOTETomek
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import joblib
import pickle

df = pd.read_csv('original_data')

x = df.drop(['TARGET'], axis=1)
y = df['TARGET']

select = SelectKBest(score_func=f_regression, k=3)
x_selected = select.fit_transform(x, y)

selected_indices = select.get_support(indices=True)

selected_columns = x.columns[selected_indices]

X_train, X_test, y_train, y_test = train_test_split(x_selected, y, test_size=0.30, random_state=42, stratify=y)

resampler = SMOTETomek()
X_train_resampled, y_train_resampled = resampler.fit_resample(X_train, y_train)

model = GradientBoostingClassifier(learning_rate=0.1, n_estimators=50, max_depth=5,
                                   min_samples_split=2, min_samples_leaf=10,
                                   subsample=0.8, max_features='sqrt')
selected_model = model.fit(X_train_resampled, y_train_resampled)

# Convert selected_columns to a DataFrame 
selected_columns_df = pd.DataFrame(selected_columns, columns=['Selected Columns'])

# Save the selected_columns DataFrame to a CSV file
selected_columns_df.to_csv('selected_columns.csv',header=False, index=False)
# Save the trained model
joblib.dump(selected_model, 'trained_model.pkl')

y_pred = selected_model.predict(X_test)

confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)
print("Confusion Matrix:")
print(confusion)
print("\nClassification Report:")
print(report)
print("\nSelected Columns:")
print(selected_columns)
accuracy_positive = accuracy_score(y_test[y_test == 1], y_pred[y_test == 1])
accuracy_negative = accuracy_score(y_test[y_test == 0], y_pred[y_test == 0])
avg_accPN = (accuracy_positive + accuracy_negative) / 2
print(avg_accPN)
# Out:
# Confusion Matrix:
# [[23047  5074]
#  [   24   132]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.85      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.83      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
#
# Selected Columns:
# Index(['CUSTOMER_WITH_ORANGE_MONTHS', 'COMMITMENT_FG',
#        'Disconnection_TOTAL_MIN_day'],
#       dtype='object')
# 0.8328596477310961

# %%
import pickle
pickle.dump(model,open('churnmodel.pkl','wb'))

# %%
import tkinter as tk
from tkinter import filedialog
import pandas as pd
import joblib
import warnings

selected_columns = [] 
selected_model = None 
input_data = pd.DataFrame()  
predicted_data = pd.DataFrame()  
feature_names = []

warnings.filterwarnings("ignore")
# Function to load the model
def load_model():
    model_file = filedialog.askopenfilename(filetypes=[("Model File", "*.pkl")])
    if model_file:
        global selected_model, selected_columns
        selected_model = joblib.load(model_file)
        status_label.config(text="Model loaded successfully!")
        selected_columns = pd.read_csv('selected_columns.csv', header=None).values.flatten().tolist()

# Function to enter data manually
def enter_data_manually():
    global input_data, selected_columns
    input_data = pd.DataFrame(columns=selected_columns)

    def submit_data():
        values = []
        for entry in data_entries:
            values.append(entry.get())
        input_data.loc[len(input_data)] = values
        status_label.config(text="Data entered successfully!")
        clear_entries()

    def clear_entries():
        for entry in data_entries:
            entry.delete(0, tk.END)

    # Create a new window for entering data manually
    manual_entry_window = tk.Toplevel(window)
    manual_entry_window.title("Manual Data Entry")

    # Create data entry labels and entry fields for selected columns
    data_entries = []
    for i, column in enumerate(selected_columns):
        tk.Label(manual_entry_window, text=column).grid(row=i, column=0)
        entry = tk.Entry(manual_entry_window)
        entry.grid(row=i, column=1)
        data_entries.append(entry)

    # Create submit and clear buttons
    submit_button = tk.Button(manual_entry_window, text="Submit", command=submit_data)
    submit_button.grid(row=len(selected_columns), column=0, pady=10)
    clear_button = tk.Button(manual_entry_window, text="Clear", command=clear_entries)
    clear_button.grid(row=len(selected_columns), column=1, pady=10)


# Function to predict using the loaded model
def predict():
    global predicted_data
    try:
        input_data_selected = input_data[selected_columns]  # Select only the desired columns
        predicted_data = input_data.copy()
        predicted_data['Prediction'] = selected_model.predict(input_data_selected)
        status_label.config(text="Prediction complete!")
        prediction_label.config(text="Prediction: {}".format(predicted_data['Prediction'].values[0]))
    except Exception as e:
        status_label.config(text="Prediction error: {}".format(str(e)))
        prediction_label.config(text="")

# Function to export the predicted data
def export_data():
    export_file = filedialog.asksaveasfilename(defaultextension=".csv", filetypes=[("CSV File", "*.csv")])
    if export_file:
        predicted_data.to_csv(export_file, index=False)
        status_label.config(text="Data exported successfully!")

def import_data():
    data_file = filedialog.askopenfilename(filetypes=[("CSV Files", "*.csv")])
    if data_file:
        global input_data, selected_columns
        input_data = pd.read_csv(data_file)
        status_label.config(text="Data imported successfully!")

# Create the main window
window = tk.Tk()
window.title("Model Deployment")

# Create buttons and labels
load_model_button = tk.Button(window, text="Load Model", command=load_model)
load_model_button.pack()

import_data_button = tk.Button(window, text="Import Data", command=import_data)
import_data_button.pack()

enter_data_button = tk.Button(window, text="Enter Data Manually", command=enter_data_manually)
enter_data_button.pack()

predict_button = tk.Button(window, text="Predict", command=predict)
predict_button.pack()

export_data_button = tk.Button(window, text="Export Predicted Data", command=export_data)
export_data_button.pack()

status_label = tk.Label(window, text="")
status_label.pack()

prediction_label = tk.Label(window, text="")
prediction_label.pack()

# Run the main event loop
window.mainloop()

# %% [markdown]
# Hyperparameters

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.combine import SMOTETomek
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.ensemble import GradientBoostingClassifier
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, classification_report
import datetime
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
df = pd.read_csv('original_data')
from sklearn.feature_selection import SelectKBest
results = []
df = pd.read_csv('original_data')

x = df.drop(['TARGET'], axis=1)
y = df['TARGET']

best_model = None
best_avg_accPN = 0.0
progress_bar = tqdm(total=2916)
# Define the hyperparameters to search over
learning_rates = [0.1, 0.01, 0.001]
n_estimators = [50, 100, 200]
max_depths = [3, 5, 7]
min_samples_splits = [2, 5, 10]
min_samples_leafs = [1, 5, 10]
subsamples = [0.5, 0.8]
max_features = ['sqrt', 'log2', None]
timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
for p in range(3, 5):
    select = SelectKBest(score_func=f_regression, k=p)
    z = select.fit_transform(x, y)
    X_train, X_test, y_train, y_test = train_test_split(z, y, test_size=0.30, random_state=42, stratify=y)

    resampler = SMOTETomek()
    X_train_resampled, y_train_resampled = resampler.fit_resample(X_train, y_train)

    for lr in learning_rates:
        for est in n_estimators:
            for depth in max_depths:
                for split in min_samples_splits:
                    for leaf in min_samples_leafs:
                        for subsample in subsamples:
                            for feature in max_features:
                                model = GradientBoostingClassifier(learning_rate=lr, n_estimators=est, max_depth=depth,
                                                                   min_samples_split=split, min_samples_leaf=leaf,
                                                                   subsample=subsample, max_features=feature)
                                selected_model = model.fit(X_train_resampled, y_train_resampled)
                                y_pred = selected_model.predict(X_test)
                                progress_bar.update(1)

                                accuracy_positive = accuracy_score(y_test[y_test == 1], y_pred[y_test == 1])
                                accuracy_negative = accuracy_score(y_test[y_test == 0], y_pred[y_test == 0])
                                avg_accPN = (accuracy_positive + accuracy_negative) / 2

                                f1 = f1_score(y_test, y_pred, average='weighted')
                                recall = recall_score(y_test, y_pred, average='weighted')
                                precision = precision_score(y_test, y_pred, average='weighted')
                                accuracy = accuracy_score(y_test, y_pred)
                                progress_bar.update(1)
                                # Calculate accuracy for positive and negative classes
                                confusion = confusion_matrix(y_test,y_pred)
                                report = classification_report(y_test,y_pred)
                                result = {
                                    'F1 Score': f1,
                                    'Recall Score': recall,
                                    'Precision Score': precision,
                                    'Accuracy': accuracy,
                                    'Accuracy (Positive)': accuracy_positive,
                                    'Accuracy (Negative)': accuracy_negative,
                                    'Accuracy (Positive)+(Negative) AVG': avg_accPN,
                                    'SelectKBest N features': p,
                                    'learning_rate': lr,
                                    'n_estimators': est,
                                    'max_depth': depth,
                                    'min_samples_split': split,
                                    'min_samples_leaf': leaf,
                                    'subsample': subsample,
                                    'max_features': feature,
                                    'confusion_matrix': confusion,
                                    'classification_report': report}
          
                                results.append(result)
                                # Save the results incrementally in a text file
                                filename = f'results_{timestamp}.txt'
                                with open(filename, 'a') as file:
                                    file.write(str(result))
                                    file.write('\n')
# Sort the results based on the average accuracy
results = sorted(results, key=lambda x: x['Accuracy (Positive)+(Negative) AVG'], reverse=True)
progress_bar.close()
# Out:
#   7%|▋         | 205/2916 [03:11<49:43,  1.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5188\1330653570.py in <module>
#      47                                                                    min_samples_split=split, min_samples_leaf=leaf,
#      48                                                                    subsample=subsample, max_features=feature)
# ---> 49                                 selected_model = model.fit(X_train_resampled, y_train_resampled)
#      50                                 y_pred = selected_model.predict(X_test)
#      51                                 progress_bar.update(1)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#     584
#     585         # fit the boosting stages
# --> 586         n_stages = self._fit_stages(
#     587             X,
#     588             y,
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     655                 # OOB score before adding this stage
#     656                 old_oob_score = loss_(
# --> 657                     y[~sample_mask],
#     658                     raw_predictions[~sample_mask],
#     659                     sample_weight[~sample_mask],
#
# KeyboardInterrupt:

# %%
for result in results:
    print("F1 Score:", result['F1 Score'])
    print("Recall Score:", result['Recall Score'])
    print("Precision Score:", result['Precision Score'])
    print("Accuracy:", result['Accuracy'])
    print("Accuracy (Positive):", result['Accuracy (Positive)'])
    print("Accuracy (Negative):", result['Accuracy (Negative)'])
    print("Accuracy (Positive)+(Negative) AVG:", result['Accuracy (Positive)+(Negative) AVG'])
    print("SelectKBest N features:", result['SelectKBest N features'])
    print("Learning Rate:", result['learning_rate'])
    print("Number of Estimators:", result['n_estimators'])
    print("Max Depth:", result['max_depth'])
    print("Min Samples Split:", result['min_samples_split'])
    print("Min Samples Leaf:", result['min_samples_leaf'])
    print("Subsample:", result['subsample'])
    print("Max Features:", result['max_features'])
    print(result['confusion_matrix'])
    print(result['classification_report'])
    print('__________________________________')
# Out:
# F1 Score: 0.8986406043360136
# Recall Score: 0.8245570605085405
# Precision Score: 0.9936859910892953
# Accuracy: 0.8245570605085405
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.824366132072117
# Accuracy (Positive)+(Negative) AVG: 0.8416702455232379
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt
# [[23182  4939]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8983849084785792
# Recall Score: 0.8241326873430703
# Precision Score: 0.9936851593320437
# Accuracy: 0.8241326873430703
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8239394047153373
# Accuracy (Positive)+(Negative) AVG: 0.8414568818448481
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: log2
# [[23170  4951]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8983422811923011
# Recall Score: 0.8240619584821587
# Precision Score: 0.9936850208144852
# Accuracy: 0.8240619584821587
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8238682834892074
# Accuracy (Positive)+(Negative) AVG: 0.8414213212317831
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: log2
# [[23168  4953]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8983422811923011
# Recall Score: 0.8240619584821587
# Precision Score: 0.9936850208144852
# Accuracy: 0.8240619584821587
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8238682834892074
# Accuracy (Positive)+(Negative) AVG: 0.8414213212317831
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: log2
# [[23168  4953]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8983422811923011
# Recall Score: 0.8240619584821587
# Precision Score: 0.9936850208144852
# Accuracy: 0.8240619584821587
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8238682834892074
# Accuracy (Positive)+(Negative) AVG: 0.8414213212317831
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[23168  4953]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8983422811923011
# Recall Score: 0.8240619584821587
# Precision Score: 0.9936850208144852
# Accuracy: 0.8240619584821587
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8238682834892074
# Accuracy (Positive)+(Negative) AVG: 0.8414213212317831
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: log2
# [[23168  4953]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8980651250123316
# Recall Score: 0.8236022208862326
# Precision Score: 0.9936841212008095
# Accuracy: 0.8236022208862326
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8234059955193628
# Accuracy (Positive)+(Negative) AVG: 0.8411901772468608
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: sqrt
# [[23155  4966]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.89802247346889
# Recall Score: 0.8235314920253209
# Precision Score: 0.9936839829135613
# Accuracy: 0.8235314920253209
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8233348742932328
# Accuracy (Positive)+(Negative) AVG: 0.8411546166337959
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: sqrt
# [[23153  4968]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.89802247346889
# Recall Score: 0.8235314920253209
# Precision Score: 0.9936839829135613
# Accuracy: 0.8235314920253209
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8233348742932328
# Accuracy (Positive)+(Negative) AVG: 0.8411546166337959
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: sqrt
# [[23153  4968]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8977451595294108
# Recall Score: 0.823071754429395
# Precision Score: 0.9936830847866365
# Accuracy: 0.823071754429395
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8228725863233882
# Accuracy (Positive)+(Negative) AVG: 0.8409234726488736
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: sqrt
# [[23140  4981]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8976811445729754
# Recall Score: 0.8229656611380274
# Precision Score: 0.9936828777077736
# Accuracy: 0.8229656611380274
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8227659044841933
# Accuracy (Positive)+(Negative) AVG: 0.8408701317292762
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[23137  4984]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8974677087228609
# Recall Score: 0.8226120168334689
# Precision Score: 0.9936821879317336
# Accuracy: 0.8226120168334689
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8224102983535436
# Accuracy (Positive)+(Negative) AVG: 0.8406923286639513
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[23127  4994]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8974677087228609
# Recall Score: 0.8226120168334689
# Precision Score: 0.9936821879317336
# Accuracy: 0.8226120168334689
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8224102983535436
# Accuracy (Positive)+(Negative) AVG: 0.8406923286639513
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[23127  4994]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8972755471493554
# Recall Score: 0.8222937369593663
# Precision Score: 0.9936815677693548
# Accuracy: 0.8222937369593663
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8220902528359589
# Accuracy (Positive)+(Negative) AVG: 0.8405323059051589
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: sqrt
# [[23118  5003]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8971687623309776
# Recall Score: 0.822116914807087
# Precision Score: 0.9936812234931546
# Accuracy: 0.822116914807087
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.821912449770634
# Accuracy (Positive)+(Negative) AVG: 0.8404434043724964
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: sqrt
# [[23113  5008]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8971046817026228
# Recall Score: 0.8220108215157195
# Precision Score: 0.9936810170155836
# Accuracy: 0.8220108215157195
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8218057679314391
# Accuracy (Positive)+(Negative) AVG: 0.840390063452899
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: sqrt
# [[23110  5011]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8970405937692947
# Recall Score: 0.8219047282243519
# Precision Score: 0.9936808106039002
# Accuracy: 0.8219047282243519
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8216990860922442
# Accuracy (Positive)+(Negative) AVG: 0.8403367225333016
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: log2
# [[23107  5014]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8969764985293762
# Recall Score: 0.8217986349329844
# Precision Score: 0.9936806042579212
# Accuracy: 0.8217986349329844
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8215924042530494
# Accuracy (Positive)+(Negative) AVG: 0.8402833816137041
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: None
# [[23104  5017]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8962495746588717
# Recall Score: 0.8205962442974856
# Precision Score: 0.9936782702057273
# Accuracy: 0.8205962442974856
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8203833434088403
# Accuracy (Positive)+(Negative) AVG: 0.8396788511915996
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: sqrt
# [[23070  5051]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8962495746588717
# Recall Score: 0.8205962442974856
# Precision Score: 0.9936782702057273
# Accuracy: 0.8205962442974856
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8203833434088403
# Accuracy (Positive)+(Negative) AVG: 0.8396788511915996
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.5
# Max Features: sqrt
# [[23070  5051]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8962495746588717
# Recall Score: 0.8205962442974856
# Precision Score: 0.9936782702057273
# Accuracy: 0.8205962442974856
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8203833434088403
# Accuracy (Positive)+(Negative) AVG: 0.8396788511915996
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: sqrt
# [[23070  5051]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.896228180310553
# Recall Score: 0.8205608798670297
# Precision Score: 0.9936782016818407
# Accuracy: 0.8205608798670297
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8203477827957754
# Accuracy (Positive)+(Negative) AVG: 0.8396610708850671
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.5
# Max Features: log2
# [[23069  5052]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: log2
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: log2
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: sqrt
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: log2
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: log2
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: sqrt
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 0.5
# Max Features: log2
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: log2
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: sqrt
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.895907167358419
# Recall Score: 0.820030413410192
# Precision Score: 0.9936771746654415
# Accuracy: 0.820030413410192
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8198143735998008
# Accuracy (Positive)+(Negative) AVG: 0.8393943662870799
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[23054  5067]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8958857599770808
# Recall Score: 0.8199950489797362
# Precision Score: 0.9936771062535108
# Accuracy: 0.8199950489797362
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8197788129867359
# Accuracy (Positive)+(Negative) AVG: 0.8393765859805474
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: None
# [[23053  5068]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8958857599770808
# Recall Score: 0.8199950489797362
# Precision Score: 0.9936771062535108
# Accuracy: 0.8199950489797362
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8197788129867359
# Accuracy (Positive)+(Negative) AVG: 0.8393765859805474
# SelectKBest N features: 4
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: sqrt
# [[23053  5068]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8956716413249536
# Recall Score: 0.8196414046751777
# Precision Score: 0.9936764225149183
# Accuracy: 0.8196414046751777
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8194232068560862
# Accuracy (Positive)+(Negative) AVG: 0.8391987829152225
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: sqrt
# [[23043  5078]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8956502249745547
# Recall Score: 0.8196060402447218
# Precision Score: 0.9936763541789875
# Accuracy: 0.8196060402447218
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8193876462430212
# Accuracy (Positive)+(Negative) AVG: 0.8391810026086901
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.5
# Max Features: log2
# [[23042  5079]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8956502249745547
# Recall Score: 0.8196060402447218
# Precision Score: 0.9936763541789875
# Accuracy: 0.8196060402447218
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8193876462430212
# Accuracy (Positive)+(Negative) AVG: 0.8391810026086901
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.5
# Max Features: sqrt
# [[23042  5079]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8956502249745547
# Recall Score: 0.8196060402447218
# Precision Score: 0.9936763541789875
# Accuracy: 0.8196060402447218
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8193876462430212
# Accuracy (Positive)+(Negative) AVG: 0.8391810026086901
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: log2
# [[23042  5079]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8956502249745547
# Recall Score: 0.8196060402447218
# Precision Score: 0.9936763541789875
# Accuracy: 0.8196060402447218
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8193876462430212
# Accuracy (Positive)+(Negative) AVG: 0.8391810026086901
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: log2
# [[23042  5079]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8956502249745547
# Recall Score: 0.8196060402447218
# Precision Score: 0.9936763541789875
# Accuracy: 0.8196060402447218
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8193876462430212
# Accuracy (Positive)+(Negative) AVG: 0.8391810026086901
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: sqrt
# [[23042  5079]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8956502249745547
# Recall Score: 0.8196060402447218
# Precision Score: 0.9936763541789875
# Accuracy: 0.8196060402447218
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8193876462430212
# Accuracy (Positive)+(Negative) AVG: 0.8391810026086901
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: log2
# [[23042  5079]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8956073898265166
# Recall Score: 0.8195353113838102
# Precision Score: 0.99367621752773
# Accuracy: 0.8195353113838102
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8193165250168913
# Accuracy (Positive)+(Negative) AVG: 0.8391454419956251
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 50
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: log2
# [[23040  5081]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8956073898265166
# Recall Score: 0.8195353113838102
# Precision Score: 0.99367621752773
# Accuracy: 0.8195353113838102
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8193165250168913
# Accuracy (Positive)+(Negative) AVG: 0.8391454419956251
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 0.5
# Max Features: log2
# [[23040  5081]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8955645514150938
# Recall Score: 0.8194645825228984
# Precision Score: 0.9936760809039015
# Accuracy: 0.8194645825228984
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8192454037907614
# Accuracy (Positive)+(Negative) AVG: 0.8391098813825602
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 3
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: None
# [[23038  5083]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8955431309854643
# Recall Score: 0.8194292180924426
# Precision Score: 0.9936760126022568
# Accuracy: 0.8194292180924426
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8192098431776964
# Accuracy (Positive)+(Negative) AVG: 0.8390921010760277
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 50
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[23037  5084]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.48     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8954360165957526
# Recall Score: 0.8192523959401634
# Precision Score: 0.993675671196473
# Accuracy: 0.8192523959401634
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8190320401123715
# Accuracy (Positive)+(Negative) AVG: 0.8390031995433652
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 50
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: sqrt
# [[23032  5089]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8954360165957526
# Recall Score: 0.8192523959401634
# Precision Score: 0.993675671196473
# Accuracy: 0.8192523959401634
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8190320401123715
# Accuracy (Positive)+(Negative) AVG: 0.8390031995433652
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 50
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: log2
# [[23032  5089]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8954360165957526
# Recall Score: 0.8192523959401634
# Precision Score: 0.993675671196473
# Accuracy: 0.8192523959401634
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8190320401123715
# Accuracy (Positive)+(Negative) AVG: 0.8390031995433652
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: sqrt
# [[23032  5089]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8954145912690803
# Recall Score: 0.8192170315097075
# Precision Score: 0.9936756029357591
# Accuracy: 0.8192170315097075
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8189964794993065
# Accuracy (Positive)+(Negative) AVG: 0.8389854192368327
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: log2
# [[23031  5090]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8954145912690803
# Recall Score: 0.8192170315097075
# Precision Score: 0.9936756029357591
# Accuracy: 0.8192170315097075
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8189964794993065
# Accuracy (Positive)+(Negative) AVG: 0.8389854192368327
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: log2
# [[23031  5090]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8954145912690803
# Recall Score: 0.8192170315097075
# Precision Score: 0.9936756029357591
# Accuracy: 0.8192170315097075
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8189964794993065
# Accuracy (Positive)+(Negative) AVG: 0.8389854192368327
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 100
# Max Depth: 3
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.5
# Max Features: log2
# [[23031  5090]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8953931651260256
# Recall Score: 0.8191816670792517
# Precision Score: 0.9936755346818443
# Accuracy: 0.8191816670792517
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8189609188862416
# Accuracy (Positive)+(Negative) AVG: 0.8389676389303002
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: log2
# [[23030  5091]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8953931651260256
# Recall Score: 0.8191816670792517
# Precision Score: 0.9936755346818443
# Accuracy: 0.8191816670792517
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8189609188862416
# Accuracy (Positive)+(Negative) AVG: 0.8389676389303002
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: log2
# [[23030  5091]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8953931651260256
# Recall Score: 0.8191816670792517
# Precision Score: 0.9936755346818443
# Accuracy: 0.8191816670792517
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8189609188862416
# Accuracy (Positive)+(Negative) AVG: 0.8389676389303002
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 100
# Max Depth: 5
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt
# [[23030  5091]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8953931651260256
# Recall Score: 0.8191816670792517
# Precision Score: 0.9936755346818443
# Accuracy: 0.8191816670792517
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8189609188862416
# Accuracy (Positive)+(Negative) AVG: 0.8389676389303002
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: sqrt
# [[23030  5091]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# weighted avg       0.99      0.82      0.90     28277
#
# __________________________________
# F1 Score: 0.8953931651260256
# Recall Score: 0.8191816670792517
# Precision Score: 0.9936755346818443
# Accuracy: 0.8191816670792517
# Accuracy (Positive): 0.8589743589743589
# Accuracy (Negative): 0.8189609188862416
# Accuracy (Positive)+(Negative) AVG: 0.8389676389303002
# SelectKBest N features: 3
# Learning Rate: 0.01
# Number of Estimators: 200
# Max Depth: 5
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: sqrt
# [[23030  5091]
#  [   22   134]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90     28121
#            1       0.03      0.86      0.05       156
#
#     accuracy                           0.82     28277
#    macro avg       0.51      0.84      0.47     28277
# ...
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: None
# [[25070  3051]
#  [   59    97]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.62      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.76      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.9295502180458199
# Recall Score: 0.877320790748665
# Precision Score: 0.9923498628538721
# Accuracy: 0.877320790748665
# Accuracy (Positive): 0.6346153846153846
# Accuracy (Negative): 0.8786671882223249
# Accuracy (Positive)+(Negative) AVG: 0.7566412864188548
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: None
# [[24709  3412]
#  [   57    99]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93     28121
#            1       0.03      0.63      0.05       156
#
#     accuracy                           0.88     28277
#    macro avg       0.51      0.76      0.49     28277
# weighted avg       0.99      0.88      0.93     28277
#
# __________________________________
# F1 Score: 0.9354926125891312
# Recall Score: 0.8878240265940517
# Precision Score: 0.9923091502989156
# Accuracy: 0.8878240265940517
# Accuracy (Positive): 0.6217948717948718
# Accuracy (Negative): 0.8892998115287507
# Accuracy (Positive)+(Negative) AVG: 0.7555473416618113
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: None
# [[25008  3113]
#  [   59    97]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.62      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.76      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.9314777935100321
# Recall Score: 0.8807157760724263
# Precision Score: 0.9923217375570548
# Accuracy: 0.8807157760724263
# Accuracy (Positive): 0.6282051282051282
# Accuracy (Negative): 0.882116567689627
# Accuracy (Positive)+(Negative) AVG: 0.7551608479473776
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: None
# [[24806  3315]
#  [   58    98]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94     28121
#            1       0.03      0.63      0.05       156
#
#     accuracy                           0.88     28277
#    macro avg       0.51      0.76      0.50     28277
# weighted avg       0.99      0.88      0.93     28277
#
# __________________________________
# F1 Score: 0.9344365693418256
# Recall Score: 0.8859497117798918
# Precision Score: 0.9923014829759951
# Accuracy: 0.8859497117798918
# Accuracy (Positive): 0.6217948717948718
# Accuracy (Negative): 0.8874150990363073
# Accuracy (Positive)+(Negative) AVG: 0.7546049854155896
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: None
# [[24955  3166]
#  [   59    97]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.62      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.75      0.50     28277
# weighted avg       0.99      0.89      0.93     28277
#
# __________________________________
# F1 Score: 0.9379151087007981
# Recall Score: 0.8921384871096651
# Precision Score: 0.9922861053552107
# Accuracy: 0.8921384871096651
# Accuracy (Positive): 0.6153846153846154
# Accuracy (Negative): 0.893673766935742
# Accuracy (Positive)+(Negative) AVG: 0.7545291911601787
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: None
# [[25131  2990]
#  [   60    96]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.62      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.75      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.9333186327314005
# Recall Score: 0.8839693036743643
# Precision Score: 0.992293452728844
# Accuracy: 0.8839693036743643
# Accuracy (Positive): 0.6217948717948718
# Accuracy (Negative): 0.8854237047046691
# Accuracy (Positive)+(Negative) AVG: 0.7536092882497705
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.8
# Max Features: None
# [[24899  3222]
#  [   59    97]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.62      0.06       156
#
#     accuracy                           0.88     28277
#    macro avg       0.51      0.75      0.50     28277
# weighted avg       0.99      0.88      0.93     28277
#
# __________________________________
# F1 Score: 0.9316977372630767
# Recall Score: 0.8811047848074407
# Precision Score: 0.9922819569001621
# Accuracy: 0.8811047848074407
# Accuracy (Positive): 0.6217948717948718
# Accuracy (Negative): 0.8825432950464066
# Accuracy (Positive)+(Negative) AVG: 0.7521690834206392
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: None
# [[24818  3303]
#  [   59    97]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94     28121
#            1       0.03      0.62      0.05       156
#
#     accuracy                           0.88     28277
#    macro avg       0.51      0.75      0.50     28277
# weighted avg       0.99      0.88      0.93     28277
#
# __________________________________
# F1 Score: 0.9361075722235039
# Recall Score: 0.888920323938183
# Precision Score: 0.9922315411521424
# Accuracy: 0.888920323938183
# Accuracy (Positive): 0.6089743589743589
# Accuracy (Negative): 0.8904733117598947
# Accuracy (Positive)+(Negative) AVG: 0.7497238353671268
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: None
# [[25041  3080]
#  [   61    95]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.61      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.75      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.9373776161348608
# Recall Score: 0.8911836474873572
# Precision Score: 0.9922000945698178
# Accuracy: 0.8911836474873572
# Accuracy (Positive): 0.6025641025641025
# Accuracy (Negative): 0.8927847516091177
# Accuracy (Positive)+(Negative) AVG: 0.7476744270866101
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 1
# Subsample: 0.5
# Max Features: None
# [[25106  3015]
#  [   62    94]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.60      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.75      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.9335369939071296
# Recall Score: 0.8843583124093787
# Precision Score: 0.9922126126384135
# Accuracy: 0.8843583124093787
# Accuracy (Positive): 0.6089743589743589
# Accuracy (Negative): 0.8858859926745137
# Accuracy (Positive)+(Negative) AVG: 0.7474301758244364
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 0.5
# Max Features: None
# [[24912  3209]
#  [   61    95]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.61      0.05       156
#
#     accuracy                           0.88     28277
#    macro avg       0.51      0.75      0.50     28277
# weighted avg       0.99      0.88      0.93     28277
#
# __________________________________
# F1 Score: 0.9368020578487886
# Recall Score: 0.8901580790041377
# Precision Score: 0.9921957269512837
# Accuracy: 0.8901580790041377
# Accuracy (Positive): 0.6025641025641025
# Accuracy (Negative): 0.8917534938302336
# Accuracy (Positive)+(Negative) AVG: 0.7471587981971681
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 10
# Subsample: 0.5
# Max Features: None
# [[25077  3044]
#  [   62    94]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.60      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.75      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.9330974458552173
# Recall Score: 0.88358029493935
# Precision Score: 0.9922094215364333
# Accuracy: 0.88358029493935
# Accuracy (Positive): 0.6089743589743589
# Accuracy (Negative): 0.8851036591870843
# Accuracy (Positive)+(Negative) AVG: 0.7470390090807216
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: None
# [[24890  3231]
#  [   61    95]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.61      0.05       156
#
#     accuracy                           0.88     28277
#    macro avg       0.51      0.75      0.50     28277
# weighted avg       0.99      0.88      0.93     28277
#
# __________________________________
# F1 Score: 0.9328375536572384
# Recall Score: 0.883120557343424
# Precision Score: 0.9922075406079701
# Accuracy: 0.883120557343424
# Accuracy (Positive): 0.6089743589743589
# Accuracy (Negative): 0.8846413712172397
# Accuracy (Positive)+(Negative) AVG: 0.7468078650957993
# SelectKBest N features: 3
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: None
# [[24877  3244]
#  [   61    95]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94     28121
#            1       0.03      0.61      0.05       156
#
#     accuracy                           0.88     28277
#    macro avg       0.51      0.75      0.50     28277
# weighted avg       0.99      0.88      0.93     28277
#
# __________________________________
# F1 Score: 0.9350511692918068
# Recall Score: 0.8870460091240231
# Precision Score: 0.9921414929380376
# Accuracy: 0.8870460091240231
# Accuracy (Positive): 0.5961538461538461
# Accuracy (Negative): 0.8886597204935813
# Accuracy (Positive)+(Negative) AVG: 0.7424067833237138
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: None
# [[24990  3131]
#  [   63    93]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.60      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.74      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.9376135021912783
# Recall Score: 0.8916080206528274
# Precision Score: 0.9921199691854866
# Accuracy: 0.8916080206528274
# Accuracy (Positive): 0.5897435897435898
# Accuracy (Negative): 0.8932826001920273
# Accuracy (Positive)+(Negative) AVG: 0.7415130949678086
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 5
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: None
# [[25120  3001]
#  [   64    92]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.59      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.74      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.9361843045413999
# Recall Score: 0.8890617816600064
# Precision Score: 0.9921089900930804
# Accuracy: 0.8890617816600064
# Accuracy (Positive): 0.5897435897435898
# Accuracy (Negative): 0.8907222360513495
# Accuracy (Positive)+(Negative) AVG: 0.7402329128974696
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 5
# Subsample: 0.8
# Max Features: None
# [[25048  3073]
#  [   64    92]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.59      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.74      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.935985523650865
# Recall Score: 0.8887081373554478
# Precision Score: 0.9921074753220134
# Accuracy: 0.8887081373554478
# Accuracy (Positive): 0.5897435897435898
# Accuracy (Negative): 0.8903666299206998
# Accuracy (Positive)+(Negative) AVG: 0.7400551098321448
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 10
# Min Samples Leaf: 5
# Subsample: 0.5
# Max Features: None
# [[25038  3083]
#  [   64    92]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.59      0.06       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.74      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.9359448407933187
# Recall Score: 0.8886374084945362
# Precision Score: 0.9920661200453038
# Accuracy: 0.8886374084945362
# Accuracy (Positive): 0.5833333333333334
# Accuracy (Negative): 0.8903310693076348
# Accuracy (Positive)+(Negative) AVG: 0.7368322013204841
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.5
# Max Features: None
# [[25037  3084]
#  [   65    91]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     28121
#            1       0.03      0.58      0.05       156
#
#     accuracy                           0.89     28277
#    macro avg       0.51      0.74      0.50     28277
# weighted avg       0.99      0.89      0.94     28277
#
# __________________________________
# F1 Score: 0.9315741642576341
# Recall Score: 0.8808925982247056
# Precision Score: 0.9920332528226627
# Accuracy: 0.8808925982247056
# Accuracy (Positive): 0.5833333333333334
# Accuracy (Negative): 0.8825432950464066
# Accuracy (Positive)+(Negative) AVG: 0.73293831418987
# SelectKBest N features: 4
# Learning Rate: 0.1
# Number of Estimators: 200
# Max Depth: 7
# Min Samples Split: 2
# Min Samples Leaf: 10
# Subsample: 0.8
# Max Features: None
# [[24818  3303]
#  [   65    91]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94     28121
#            1       0.03      0.58      0.05       156
#
#     accuracy                           0.88     28277
#    macro avg       0.51      0.73      0.49     28277
# weighted avg       0.99      0.88      0.93     28277
#
# __________________________________
